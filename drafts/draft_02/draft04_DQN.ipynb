# %% [markdown]
# # LunarLander-v3 Project using DQN and PPO

# %% [markdown]
# # 1. Libraries

# %%
# ====== Libraries  ======
import os
import random
import numpy as np
import random

import gymnasium as gym

# Plots
import matplotlib.pyplot as plt
# %matplotlib inline

# DQN 
from stable_baselines3 import DQN
from stable_baselines3.common.vec_env import DummyVecEnv
from stable_baselines3.common.evaluation import evaluate_policy
from stable_baselines3.common.callbacks import BaseCallback
from stable_baselines3.common.monitor import Monitor


from collections import deque, namedtuple
import random
import numpy as np
import torch
import torch.nn.functional as F
import torch.optim as optim
import torch.nn as nn

from IPython.display import Image, display
from itertools import product

# %% [markdown]
# # 2. Create LunarLander-v3 environment

# %%
ENV_ID = "LunarLander-v3"
OUT_DIR = "runs_lunarlander"
os.makedirs(OUT_DIR, exist_ok=True)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", DEVICE)
print("Gymnasium:", gym.__version__)
# Out:
# Device: cpu
# Gymnasium: 1.2.3

# %%
env = gym.make(ENV_ID)
obs, _ = env.reset(seed=42)
print("Env:", ENV_ID)
print("Obs space:", env.observation_space)
print("Action space:", env.action_space)
print("Obs shape:", obs.shape)
print("Example obs:", obs)
env.close()
# Out:
# Env: LunarLander-v3
# Obs space: Box([ -2.5        -2.5       -10.        -10.         -6.2831855 -10.
#   -0.         -0.       ], [ 2.5        2.5       10.        10.         6.2831855 10.
#   1.         1.       ], (8,), float32)
# Action space: Discrete(4)
# Obs shape: (8,)
# Example obs: [ 0.00229702  1.4181306   0.2326471   0.3204666  -0.00265488 -0.05269805
#   0.          0.        ]

# %% [markdown]
# # 3. CLASSES (ReplayBuffer, Network, DQNAgent)

# %%
Transition = namedtuple("Transition", ["s", "a", "r", "s2", "d"])

class ReplayBuffer:
    def __init__(self, capacity, device):
        self.buf = deque(maxlen=capacity)
        self.device = device

    def __len__(self):
        return len(self.buf)

    def add(self, s, a, r, s2, d):
        self.buf.append(Transition(s, a, r, s2, d))

    def sample(self, batch_size):
        batch = random.sample(self.buf, batch_size)
        s  = torch.tensor(np.vstack([t.s  for t in batch]), dtype=torch.float32, device=self.device)
        a  = torch.tensor(np.vstack([t.a  for t in batch]), dtype=torch.int64,   device=self.device)
        r  = torch.tensor(np.vstack([t.r  for t in batch]), dtype=torch.float32, device=self.device)
        s2 = torch.tensor(np.vstack([t.s2 for t in batch]), dtype=torch.float32, device=self.device)
        d  = torch.tensor(np.vstack([t.d  for t in batch]).astype(np.uint8), dtype=torch.float32, device=self.device)
        return s, a, r, s2, d

class Network(nn.Module):
    def __init__(self, state_size, action_size, hidden=256, seed=0):
        super().__init__()
        torch.manual_seed(seed)
        self.net = nn.Sequential(
            nn.Linear(state_size, hidden), nn.ReLU(),
            nn.Linear(hidden, hidden), nn.ReLU(),
            nn.Linear(hidden, action_size),
        )
    def forward(self, x):
        return self.net(x)

class DQNAgent:
    def __init__(
        self, state_size, action_size,
        lr, gamma, buffer_size, batch_size, tau,
        update_every, learning_starts, grad_clip, seed
    ):
        random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)
        self.device = DEVICE
        self.action_size = action_size

        self.q = Network(state_size, action_size, seed=seed).to(self.device)
        self.q_tgt = Network(state_size, action_size, seed=seed+1).to(self.device)
        self.q_tgt.load_state_dict(self.q.state_dict())

        self.opt = optim.Adam(self.q.parameters(), lr=lr)
        self.buf = ReplayBuffer(buffer_size, self.device)

        self.gamma = gamma
        self.batch_size = batch_size
        self.tau = tau
        self.update_every = update_every
        self.learning_starts = learning_starts
        self.grad_clip = grad_clip

        self.total_steps = 0

    def act(self, state, eps):
        if random.random() < eps:
            return random.randrange(self.action_size)
        s = torch.tensor(state, dtype=torch.float32, device=self.device).unsqueeze(0)
        with torch.no_grad():
            qvals = self.q(s)
        return int(torch.argmax(qvals, dim=1).item())

    def store(self, s, a, r, s2, done):
        self.buf.add(s, a, r, s2, done)

    def soft_update(self):
        for p_tgt, p in zip(self.q_tgt.parameters(), self.q.parameters()):
            p_tgt.data.mul_(1.0 - self.tau)
            p_tgt.data.add_(self.tau * p.data)

    def train_step(self):
        if len(self.buf) < max(self.batch_size, self.learning_starts):
            return None

        s, a, r, s2, d = self.buf.sample(self.batch_size)

        with torch.no_grad():
            a2 = torch.argmax(self.q(s2), dim=1, keepdim=True)
            q2 = self.q_tgt(s2).gather(1, a2)
            y  = r + self.gamma * q2 * (1.0 - d)

        q_sa = self.q(s).gather(1, a)
        loss = F.smooth_l1_loss(q_sa, y)

        self.opt.zero_grad()
        loss.backward()
        nn.utils.clip_grad_norm_(self.q.parameters(), self.grad_clip)
        self.opt.step()

        self.soft_update()
        return float(loss.item())

# %% [markdown]
# # 4. UTILITIES (make_env, eval, gif)

# %%
def make_env(seed: int, render_mode=None):
    env = gym.make(ENV_ID, render_mode=render_mode)
    env.reset(seed=seed)
    env.action_space.seed(seed)
    return env

@torch.no_grad()
def evaluate_dqn(agent, n_episodes=20, seed=0, max_steps=1000):
    env = make_env(seed + 10_000)
    rets, lens = [], []
    for ep in range(n_episodes):
        s, _ = env.reset(seed=seed + 10_000 + ep)
        ep_ret, ep_len = 0.0, 0
        for _ in range(max_steps):
            a = agent.act(s, eps=0.0)
            s, r, terminated, truncated, _ = env.step(a)
            ep_ret += float(r); ep_len += 1
            if terminated or truncated:
                break
        rets.append(ep_ret); lens.append(ep_len)
    env.close()
    return float(np.mean(rets)), float(np.std(rets, ddof=1)), rets, lens

def moving_avg(x, w=100):
    x = np.asarray(x, float)
    if len(x) < w:
        return np.full_like(x, np.nan)
    c = np.convolve(x, np.ones(w)/w, mode="valid")
    return np.concatenate([np.full(w-1, np.nan), c])

def find_center_seed(agent, base_seed, tries, center_tol, max_steps):
    env = make_env(base_seed)
    for i in range(tries):
        s, _ = env.reset(seed=base_seed + i)
        for _ in range(max_steps):
            a = agent.act(s, eps=0.0)
            s, r, terminated, truncated, _ = env.step(a)
            if terminated or truncated:
                x = float(s[0])
                vx, vy = float(s[2]), float(s[3])
                left, right = float(s[6]), float(s[7])
                landed = (left > 0.5 or right > 0.5) and abs(vx) < 0.35 and abs(vy) < 0.35
                if landed and abs(x) < center_tol:
                    env.close()
                    return base_seed + i
                break
    env.close()
    return None

def save_gif(agent, seed_gif, gif_path, max_steps=1000, fps=30):
    import imageio
    env = make_env(seed_gif, render_mode="rgb_array")
    s, _ = env.reset(seed=seed_gif)
    frames, total_r = [], 0.0
    for _ in range(max_steps):
        frames.append(env.render())
        a = agent.act(s, eps=0.0)
        s, r, terminated, truncated, _ = env.step(a)
        total_r += float(r)
        if terminated or truncated:
            frames.append(env.render())
            break
    env.close()
    imageio.mimsave(gif_path, frames, fps=fps)
    return float(total_r)

# %% [markdown]
# # 5. SINGLE TRAIN ENTRYPOINT: run_dqn(cfg, seed)

# %%
def run_dqn(cfg: dict, seed: int, run_name: str):
    cfg = dict(cfg)
    # defaults
    cfg.setdefault("gamma", 0.99)
    cfg.setdefault("grad_clip", 10.0)
    cfg.setdefault("eps_start", 1.0)
    cfg.setdefault("total_episodes", 2500)          # ↑ mais margem p/ performance
    cfg.setdefault("max_steps", 1000)
    cfg.setdefault("solved_avg100", 200.0)
    cfg.setdefault("lr_finetune", min(cfg["lr_finetune"], cfg["lr"]))
    cfg.setdefault("eval_episodes", 20)
    cfg.setdefault("extra_after_solved", 500)       # ↑ sobe “ceiling”
    cfg.setdefault("make_gif", False)
    cfg.setdefault("gif_tries", 1200)
    cfg.setdefault("center_tol", 0.12)

    # reproducibility
    random.seed(seed); np.random.seed(seed); torch.manual_seed(seed)

    env = make_env(seed)
    state_size = env.observation_space.shape[0]
    action_size = env.action_space.n

    agent = DQNAgent(
        state_size=state_size,
        action_size=action_size,
        lr=cfg["lr"],
        gamma=cfg["gamma"],
        buffer_size=int(cfg["buffer_size"]),
        batch_size=int(cfg["batch_size"]),
        tau=cfg["tau"],
        update_every=int(cfg["update_every"]),
        learning_starts=int(cfg["learning_starts"]),
        grad_clip=cfg["grad_clip"],
        seed=seed,
    )

    scores_100 = deque(maxlen=100)
    eps = cfg["eps_start"]
    solved_at, stop_at = None, None
    finetune_done = False

    ep_returns, ep_lengths, ep_eps, step_losses = [], [], [], []
    grad_updates = 0

    for ep in range(1, cfg["total_episodes"] + 1):
        s, _ = env.reset(seed=seed + ep)
        ep_ret, ep_len = 0.0, 0

        for _ in range(cfg["max_steps"]):
            a = agent.act(s, eps=eps)
            s2, r, terminated, truncated, _ = env.step(a)
            done = terminated or truncated

            agent.store(s, a, float(r), s2, done)

            agent.total_steps += 1
            if agent.total_steps % agent.update_every == 0:
                loss = agent.train_step()
                if loss is not None:
                    step_losses.append(loss)
                    grad_updates += 1

            s = s2
            ep_ret += float(r); ep_len += 1
            if done:
                break

        ep_returns.append(ep_ret)
        ep_lengths.append(ep_len)
        ep_eps.append(eps)

        scores_100.append(ep_ret)
        avg100 = float(np.mean(scores_100))

        eps = max(cfg["eps_min"], eps * cfg["eps_decay"])

        if ep % 50 == 0:
            last_loss = float(np.mean(step_losses[-200:])) if len(step_losses) else np.nan
            print(f"{run_name} | Ep {ep:4d} | avg100: {avg100:7.2f} | eps: {eps:6.3f} | loss~: {last_loss:6.3f}")

        if len(scores_100) == 100 and avg100 >= cfg["solved_avg100"] and stop_at is None:
            solved_at = ep
            stop_at = min(cfg["total_episodes"], ep + cfg["extra_after_solved"])
            if not finetune_done:
                for g in agent.opt.param_groups:
                    g["lr"] = cfg["lr_finetune"]
                finetune_done = True
            print(f"\n {run_name} solved at ep {ep} | avg100 {avg100:.2f} | continue until ep {stop_at} | finetune_lr {cfg['lr_finetune']}\n")

        if stop_at is not None and ep >= stop_at:
            break

    env.close()

    mean_eval, std_eval, _, _ = evaluate_dqn(agent, n_episodes=cfg["eval_episodes"], seed=seed, max_steps=cfg["max_steps"])

    model_path = os.path.join(OUT_DIR, f"{run_name}_seed{seed}.pth")
    torch.save(agent.q.state_dict(), model_path)

    curves_path = os.path.join(OUT_DIR, f"{run_name}_seed{seed}_curves.npz")
    np.savez(
        curves_path,
        returns=np.array(ep_returns, float),
        lengths=np.array(ep_lengths, int),
        eps=np.array(ep_eps, float),
        losses=np.array(step_losses, float),
        solved_at_episode=np.array([-1 if solved_at is None else solved_at], int),
        total_steps=np.array([agent.total_steps], int),
        grad_updates=np.array([grad_updates], int),
    )

    res = {
        "seed": seed,
        "cfg": cfg,
        "run_name": run_name,
        "solved_at_episode": solved_at,
        "train_episodes": len(ep_returns),
        "train_total_steps": agent.total_steps,
        "grad_updates": grad_updates,
        "eval_mean": mean_eval,
        "eval_std": std_eval,
        "model_path": model_path,
        "curves_path": curves_path,
    }

    if cfg["make_gif"]:
        good = find_center_seed(agent, base_seed=seed + 1000, tries=cfg["gif_tries"], center_tol=cfg["center_tol"], max_steps=cfg["max_steps"])
        if good is not None:
            gif_path = os.path.join(OUT_DIR, f"{run_name}_seed{seed}_best.gif")
            gif_ret = save_gif(agent, seed_gif=good, gif_path=gif_path, max_steps=cfg["max_steps"], fps=30)
            res["center_gif_path"] = gif_path
            res["center_gif_seed"] = int(good)
            res["center_gif_return"] = float(gif_ret)
            print("Saved GIF:", gif_path, "| return:", round(gif_ret, 2))

    return res

# %% [markdown]
# # 6. MONTE CARLO LOOP + select best (triagem)

# %% [markdown]
# ## 6.1 Coverage Scheduler

# %%
# ---------- Coverage scheduler for (lr, gamma) ----------
class CoveragePairs:
    """
    Generates (lr, gamma) pairs with guaranteed coverage.
    It cycles through ALL combinations in random order, then reshuffles and repeats.
    """
    def __init__(self, lr_list, gamma_list, rng: random.Random):
        self.lr_list = list(lr_list)
        self.gamma_list = list(gamma_list)
        self.rng = rng
        self._pool = []
        self._refill()

    def _refill(self):
        self._pool = list(product(self.lr_list, self.gamma_list))
        self.rng.shuffle(self._pool)

    def next(self):
        if not self._pool:
            self._refill()
        return self._pool.pop()


# ---------- tuned discrete spaces ----------
LR_LIST = [2e-4, 1e-4, 3e-4, 5e-5, 3e-5]
GAMMA_LIST = [0.98, 0.99, 0.995]

TAU_LIST = [2e-3, 1e-3, 5e-4]
BATCH_LIST = [64, 128, 256]
BUFFER_LIST = [200_000, 500_000]
LEARNING_STARTS_LIST = [1000, 2000]
UPDATE_EVERY_LIST = [2, 4]
EPS_DECAY_LIST = [0.995, 0.997, 0.999]
EPS_MIN_LIST = [0.01, 0.005]
EXTRA_AFTER_SOLVED_LIST = [300, 500]

LR_FINETUNE_CANDIDATES = [1e-4, 1e-5, 3e-5]

# %% [markdown]
# ## 6.2 Sample Coverage

# %%
def sample_dqn_cfg_coverage(rng: random.Random, pair_sched: CoveragePairs):
    """
    Monte Carlo sampler with guaranteed coverage for lr and gamma.
    Other hyperparameters are sampled randomly from discrete sets.
    """
    lr, gamma = pair_sched.next()

    # Ensure lr_finetune <= lr (safe fine-tune)
    lr_ft_choices = [x for x in LR_FINETUNE_CANDIDATES if x <= lr]
    lr_finetune = rng.choice(lr_ft_choices) if lr_ft_choices else lr

    cfg = {
        # Guaranteed-coverage dimensions
        "lr": lr,
        "gamma": gamma,

        # Fine-tuning
        "lr_finetune": lr_finetune,

        # Target network update
        "tau": rng.choice(TAU_LIST),

        # Replay / training
        "batch_size": rng.choice(BATCH_LIST),
        "buffer_size": rng.choice(BUFFER_LIST),
        "learning_starts": rng.choice(LEARNING_STARTS_LIST),
        "update_every": rng.choice(UPDATE_EVERY_LIST),

        # Exploration
        "eps_decay": rng.choice(EPS_DECAY_LIST),
        "eps_min": rng.choice(EPS_MIN_LIST),

        # Training control
        "extra_after_solved": rng.choice(EXTRA_AFTER_SOLVED_LIST),
        "eval_episodes": 20,

        # Qualitative
        "make_gif": False,
    }
    return cfg

# %% [markdown]
# # 7. FINAL EVAL (3 seeds) + plots + gif do melhor

# %%
def mc_tune_dqn_coverage(n_trials=20, tune_seed=42, train_seed=42):
    """
    Monte Carlo tuning with guaranteed lr×gamma coverage.
    - tune_seed controls the sampling order (reproducible)
    - train_seed controls training randomness (fixed for fair tuning)
    """
    rng = random.Random(tune_seed)
    pair_sched = CoveragePairs(LR_LIST, GAMMA_LIST, rng)

    trials, best = [], None

    # Useful: how many trials to cover all lr×gamma at least once
    n_cover = len(LR_LIST) * len(GAMMA_LIST)
    print(f"[INFO] lr×gamma combinations: {n_cover}. If n_trials >= {n_cover}, coverage is guaranteed at least once.")

    for t in range(1, n_trials + 1):
        cfg = sample_dqn_cfg_coverage(rng, pair_sched)
        run_name = f"dqn_trial{t:02d}"

        print(f"\n=== Trial {t}/{n_trials} | cfg: {cfg} ===")
        res = run_dqn(cfg, seed=train_seed, run_name=run_name)  

        trials.append(res)
        if (best is None) or (res["eval_mean"] > best["eval_mean"]):
            best = res

        print(f"Trial {t} -> eval_mean: {res['eval_mean']:.2f} ± {res['eval_std']:.2f} | BEST: {best['eval_mean']:.2f}")

    return trials, best

# %%
# 1) Tune
dqn_trials, best_dqn = mc_tune_dqn_coverage(n_trials=20, tune_seed=42, train_seed=42)
print("\nBEST CFG:", best_dqn["cfg"])

# 2) Final 3 seeds 
FINAL_SEEDS = [42, 123, 999]
final_cfg = dict(best_dqn["cfg"])
final_cfg["eval_episodes"] = 20
final_cfg["make_gif"] = False  # gifs só no melhor final

dqn_final = []
for s in FINAL_SEEDS:
    print("\n=== FINAL seed", s, "===")
    dqn_final.append(run_dqn(final_cfg, seed=s, run_name="dqn_final"))

means = [r["eval_mean"] for r in dqn_final]
print("\nFINAL mean across seeds:", float(np.mean(means)), "| std:", float(np.std(means, ddof=1)))

# 3) Pick best FINAL seed and generate GIF (1 run extra, só para gif)
best_seed = max(dqn_final, key=lambda x: x["eval_mean"])
gif_cfg = dict(final_cfg)
gif_cfg["make_gif"] = True
gif_run = run_dqn(gif_cfg, seed=best_seed["seed"], run_name="dqn_best_gif")

from IPython.display import Image, display
display(Image(filename=gif_run["center_gif_path"]))

# 4) Plots: returns + avg100, epsilon, loss (por seed)
def load_curves(path):
    d = np.load(path, allow_pickle=True)
    return {k: d[k] for k in d.files}

plt.figure()
for r in dqn_final:
    c = load_curves(r["curves_path"])
    y = c["returns"]
    plt.plot(y, alpha=0.25, label=f"seed {r['seed']} raw")
    plt.plot(moving_avg(y, 100), linewidth=2, label=f"seed {r['seed']} avg100")
plt.title("DQN — Training Return per Episode")
plt.xlabel("Episode"); plt.ylabel("Return"); plt.legend(); plt.show()

plt.figure()
for r in dqn_final:
    c = load_curves(r["curves_path"])
    plt.plot(c["eps"], label=f"seed {r['seed']}")
plt.title("DQN — Epsilon Decay")
plt.xlabel("Episode"); plt.ylabel("Epsilon"); plt.legend(); plt.show()

plt.figure()
for r in dqn_final:
    c = load_curves(r["curves_path"])
    if len(c["losses"]) > 0:
        plt.plot(moving_avg(c["losses"], 200), label=f"seed {r['seed']} loss avg200")
plt.title("DQN — Q-loss (smoothed)")
plt.xlabel("Update step"); plt.ylabel("Loss"); plt.legend(); plt.show()
# Out:
# [INFO] lr×gamma combinations: 15. If n_trials >= 15, coverage is guaranteed at least once.
#
# === Trial 1/20 | cfg: {'lr': 5e-05, 'gamma': 0.99, 'lr_finetune': 1e-05, 'tau': 0.002, 'batch_size': 64, 'buffer_size': 200000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial01 | Ep   50 | avg100: -194.11 | eps:  0.951 | loss~:  1.689
# dqn_trial01 | Ep  100 | avg100: -177.89 | eps:  0.905 | loss~:  1.249
# dqn_trial01 | Ep  150 | avg100: -151.65 | eps:  0.861 | loss~:  1.415
# dqn_trial01 | Ep  200 | avg100: -122.76 | eps:  0.819 | loss~:  1.534
# dqn_trial01 | Ep  250 | avg100:  -97.93 | eps:  0.779 | loss~:  1.602
# dqn_trial01 | Ep  300 | avg100:  -83.08 | eps:  0.741 | loss~:  1.750
# dqn_trial01 | Ep  350 | avg100:  -72.71 | eps:  0.705 | loss~:  1.692
# dqn_trial01 | Ep  400 | avg100:  -72.09 | eps:  0.670 | loss~:  1.462
# dqn_trial01 | Ep  450 | avg100:  -65.87 | eps:  0.637 | loss~:  1.802
# dqn_trial01 | Ep  500 | avg100:  -55.52 | eps:  0.606 | loss~:  1.744
# dqn_trial01 | Ep  550 | avg100:  -47.96 | eps:  0.577 | loss~:  1.727
# dqn_trial01 | Ep  600 | avg100:  -45.49 | eps:  0.549 | loss~:  1.607
# dqn_trial01 | Ep  650 | avg100:  -43.83 | eps:  0.522 | loss~:  1.969
# dqn_trial01 | Ep  700 | avg100:  -36.98 | eps:  0.496 | loss~:  1.782
# dqn_trial01 | Ep  750 | avg100:  -27.16 | eps:  0.472 | loss~:  2.412
# dqn_trial01 | Ep  800 | avg100:  -21.64 | eps:  0.449 | loss~:  2.462
# dqn_trial01 | Ep  850 | avg100:  -17.88 | eps:  0.427 | loss~:  2.680
# dqn_trial01 | Ep  900 | avg100:  -15.52 | eps:  0.406 | loss~:  3.131
# dqn_trial01 | Ep  950 | avg100:  -15.73 | eps:  0.387 | loss~:  3.187
# dqn_trial01 | Ep 1000 | avg100:  -13.15 | eps:  0.368 | loss~:  3.510
# dqn_trial01 | Ep 1050 | avg100:  -13.69 | eps:  0.350 | loss~:  3.792
# dqn_trial01 | Ep 1100 | avg100:   -7.08 | eps:  0.333 | loss~:  3.296
# dqn_trial01 | Ep 1150 | avg100:   -5.29 | eps:  0.316 | loss~:  3.187
# dqn_trial01 | Ep 1200 | avg100:  -22.29 | eps:  0.301 | loss~:  2.612
# dqn_trial01 | Ep 1250 | avg100:  -27.38 | eps:  0.286 | loss~:  2.164
# dqn_trial01 | Ep 1300 | avg100:  -16.53 | eps:  0.272 | loss~:  2.010
# dqn_trial01 | Ep 1350 | avg100:    8.53 | eps:  0.259 | loss~:  1.843
# dqn_trial01 | Ep 1400 | avg100:   71.25 | eps:  0.246 | loss~:  1.960
# dqn_trial01 | Ep 1450 | avg100:  126.13 | eps:  0.234 | loss~:  1.909
# dqn_trial01 | Ep 1500 | avg100:  139.60 | eps:  0.223 | loss~:  1.732
# dqn_trial01 | Ep 1550 | avg100:  152.40 | eps:  0.212 | loss~:  1.502
# dqn_trial01 | Ep 1600 | avg100:  187.60 | eps:  0.202 | loss~:  1.193
#
#  dqn_trial01 solved at ep 1623 | avg100 202.34 | continue until ep 2123 | finetune_lr 1e-05
#
# dqn_trial01 | Ep 1650 | avg100:  212.12 | eps:  0.192 | loss~:  1.017
# dqn_trial01 | Ep 1700 | avg100:  224.44 | eps:  0.183 | loss~:  0.773
# dqn_trial01 | Ep 1750 | avg100:  229.49 | eps:  0.174 | loss~:  0.846
# dqn_trial01 | Ep 1800 | avg100:  209.49 | eps:  0.165 | loss~:  0.746
# dqn_trial01 | Ep 1850 | avg100:  200.46 | eps:  0.157 | loss~:  0.749
# dqn_trial01 | Ep 1900 | avg100:  219.20 | eps:  0.149 | loss~:  0.733
# dqn_trial01 | Ep 1950 | avg100:  226.72 | eps:  0.142 | loss~:  0.748
# dqn_trial01 | Ep 2000 | avg100:  220.00 | eps:  0.135 | loss~:  0.841
# dqn_trial01 | Ep 2050 | avg100:  226.02 | eps:  0.129 | loss~:  0.778
# dqn_trial01 | Ep 2100 | avg100:  233.01 | eps:  0.122 | loss~:  0.719
# Trial 1 -> eval_mean: 248.84 ± 44.98 | BEST: 248.84
#
# === Trial 2/20 | cfg: {'lr': 0.0002, 'gamma': 0.99, 'lr_finetune': 0.0001, 'tau': 0.001, 'batch_size': 256, 'buffer_size': 500000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial02 | Ep   50 | avg100: -165.90 | eps:  0.951 | loss~:  1.491
# dqn_trial02 | Ep  100 | avg100: -146.54 | eps:  0.905 | loss~:  1.263
# dqn_trial02 | Ep  150 | avg100: -131.08 | eps:  0.861 | loss~:  1.223
# dqn_trial02 | Ep  200 | avg100: -123.95 | eps:  0.819 | loss~:  1.151
# dqn_trial02 | Ep  250 | avg100: -108.92 | eps:  0.779 | loss~:  1.210
# dqn_trial02 | Ep  300 | avg100:  -93.89 | eps:  0.741 | loss~:  1.287
# dqn_trial02 | Ep  350 | avg100:  -80.92 | eps:  0.705 | loss~:  1.282
# dqn_trial02 | Ep  400 | avg100:  -76.32 | eps:  0.670 | loss~:  1.333
# dqn_trial02 | Ep  450 | avg100:  -63.99 | eps:  0.637 | loss~:  1.379
# dqn_trial02 | Ep  500 | avg100:  -54.28 | eps:  0.606 | loss~:  1.534
# dqn_trial02 | Ep  550 | avg100:  -47.21 | eps:  0.577 | loss~:  1.548
# dqn_trial02 | Ep  600 | avg100:  -34.18 | eps:  0.549 | loss~:  1.698
# dqn_trial02 | Ep  650 | avg100:  -29.06 | eps:  0.522 | loss~:  1.765
# dqn_trial02 | Ep  700 | avg100:  -27.07 | eps:  0.496 | loss~:  1.838
# dqn_trial02 | Ep  750 | avg100:  -19.17 | eps:  0.472 | loss~:  2.016
# dqn_trial02 | Ep  800 | avg100:  -15.48 | eps:  0.449 | loss~:  2.291
# dqn_trial02 | Ep  850 | avg100:  -13.00 | eps:  0.427 | loss~:  2.446
# dqn_trial02 | Ep  900 | avg100:   -6.61 | eps:  0.406 | loss~:  2.737
# dqn_trial02 | Ep  950 | avg100:   -4.09 | eps:  0.387 | loss~:  2.755
# dqn_trial02 | Ep 1000 | avg100:    2.56 | eps:  0.368 | loss~:  2.810
# dqn_trial02 | Ep 1050 | avg100:   16.67 | eps:  0.350 | loss~:  3.095
# dqn_trial02 | Ep 1100 | avg100:   20.01 | eps:  0.333 | loss~:  2.906
# dqn_trial02 | Ep 1150 | avg100:   18.83 | eps:  0.316 | loss~:  2.909
# dqn_trial02 | Ep 1200 | avg100:   17.64 | eps:  0.301 | loss~:  2.920
# dqn_trial02 | Ep 1250 | avg100:   20.49 | eps:  0.286 | loss~:  2.708
# dqn_trial02 | Ep 1300 | avg100:   31.22 | eps:  0.272 | loss~:  2.439
# dqn_trial02 | Ep 1350 | avg100:   36.64 | eps:  0.259 | loss~:  2.362
# dqn_trial02 | Ep 1400 | avg100:   60.38 | eps:  0.246 | loss~:  2.396
# dqn_trial02 | Ep 1450 | avg100:   69.33 | eps:  0.234 | loss~:  2.554
# dqn_trial02 | Ep 1500 | avg100:   91.17 | eps:  0.223 | loss~:  2.189
# dqn_trial02 | Ep 1550 | avg100:  138.45 | eps:  0.212 | loss~:  1.899
# dqn_trial02 | Ep 1600 | avg100:  151.31 | eps:  0.202 | loss~:  1.789
# dqn_trial02 | Ep 1650 | avg100:  145.94 | eps:  0.192 | loss~:  1.625
# dqn_trial02 | Ep 1700 | avg100:  159.78 | eps:  0.183 | loss~:  1.963
# dqn_trial02 | Ep 1750 | avg100:  172.50 | eps:  0.174 | loss~:  1.396
# dqn_trial02 | Ep 1800 | avg100:  169.10 | eps:  0.165 | loss~:  1.213
# dqn_trial02 | Ep 1850 | avg100:  193.48 | eps:  0.157 | loss~:  0.977
#
#  dqn_trial02 solved at ep 1865 | avg100 201.23 | continue until ep 2365 | finetune_lr 0.0001
#
# dqn_trial02 | Ep 1900 | avg100:  222.36 | eps:  0.149 | loss~:  0.859
# dqn_trial02 | Ep 1950 | avg100:  224.05 | eps:  0.142 | loss~:  0.834
# dqn_trial02 | Ep 2000 | avg100:  225.37 | eps:  0.135 | loss~:  0.746
# dqn_trial02 | Ep 2050 | avg100:  218.17 | eps:  0.129 | loss~:  0.760
# dqn_trial02 | Ep 2100 | avg100:  203.02 | eps:  0.122 | loss~:  0.658
# dqn_trial02 | Ep 2150 | avg100:  196.37 | eps:  0.116 | loss~:  0.633
# dqn_trial02 | Ep 2200 | avg100:  208.90 | eps:  0.111 | loss~:  0.619
# dqn_trial02 | Ep 2250 | avg100:  224.88 | eps:  0.105 | loss~:  0.599
# dqn_trial02 | Ep 2300 | avg100:  219.83 | eps:  0.100 | loss~:  0.552
# dqn_trial02 | Ep 2350 | avg100:  229.13 | eps:  0.095 | loss~:  0.562
# Trial 2 -> eval_mean: 260.55 ± 33.87 | BEST: 260.55
#
# === Trial 3/20 | cfg: {'lr': 0.0002, 'gamma': 0.98, 'lr_finetune': 1e-05, 'tau': 0.002, 'batch_size': 64, 'buffer_size': 500000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.997, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial03 | Ep   50 | avg100: -183.52 | eps:  0.861 | loss~:  1.508
# dqn_trial03 | Ep  100 | avg100: -145.82 | eps:  0.740 | loss~:  1.313
# dqn_trial03 | Ep  150 | avg100:  -97.82 | eps:  0.637 | loss~:  1.323
# dqn_trial03 | Ep  200 | avg100:  -65.82 | eps:  0.548 | loss~:  1.300
# dqn_trial03 | Ep  250 | avg100:  -33.06 | eps:  0.472 | loss~:  1.447
# dqn_trial03 | Ep  300 | avg100:  -16.16 | eps:  0.406 | loss~:  1.456
# dqn_trial03 | Ep  350 | avg100:   13.75 | eps:  0.349 | loss~:  1.725
# dqn_trial03 | Ep  400 | avg100:   60.09 | eps:  0.301 | loss~:  1.611
# dqn_trial03 | Ep  450 | avg100:   76.42 | eps:  0.259 | loss~:  1.413
# dqn_trial03 | Ep  500 | avg100:   89.06 | eps:  0.223 | loss~:  1.322
# dqn_trial03 | Ep  550 | avg100:  132.22 | eps:  0.192 | loss~:  1.112
# dqn_trial03 | Ep  600 | avg100:  166.12 | eps:  0.165 | loss~:  1.037
# dqn_trial03 | Ep  650 | avg100:  182.19 | eps:  0.142 | loss~:  1.182
#
#  dqn_trial03 solved at ep 685 | avg100 200.53 | continue until ep 1185 | finetune_lr 1e-05
#
# dqn_trial03 | Ep  700 | avg100:  201.71 | eps:  0.122 | loss~:  0.772
# dqn_trial03 | Ep  750 | avg100:  216.52 | eps:  0.105 | loss~:  0.926
# dqn_trial03 | Ep  800 | avg100:  217.45 | eps:  0.090 | loss~:  0.815
# dqn_trial03 | Ep  850 | avg100:  206.30 | eps:  0.078 | loss~:  0.775
# dqn_trial03 | Ep  900 | avg100:  206.71 | eps:  0.067 | loss~:  0.847
# dqn_trial03 | Ep  950 | avg100:  210.00 | eps:  0.058 | loss~:  0.752
# dqn_trial03 | Ep 1000 | avg100:  201.59 | eps:  0.050 | loss~:  0.907
# dqn_trial03 | Ep 1050 | avg100:  206.66 | eps:  0.043 | loss~:  0.790
# dqn_trial03 | Ep 1100 | avg100:  214.29 | eps:  0.037 | loss~:  0.749
# dqn_trial03 | Ep 1150 | avg100:  211.64 | eps:  0.032 | loss~:  0.666
# Trial 3 -> eval_mean: 236.23 ± 53.35 | BEST: 260.55
#
# === Trial 4/20 | cfg: {'lr': 5e-05, 'gamma': 0.995, 'lr_finetune': 3e-05, 'tau': 0.0005, 'batch_size': 128, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 2, 'eps_decay': 0.997, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial04 | Ep   50 | avg100: -170.20 | eps:  0.861 | loss~:  1.842
# dqn_trial04 | Ep  100 | avg100: -157.65 | eps:  0.740 | loss~:  1.621
# dqn_trial04 | Ep  150 | avg100: -131.83 | eps:  0.637 | loss~:  1.435
# dqn_trial04 | Ep  200 | avg100: -102.99 | eps:  0.548 | loss~:  1.289
# dqn_trial04 | Ep  250 | avg100:  -64.76 | eps:  0.472 | loss~:  1.466
# dqn_trial04 | Ep  300 | avg100:  -31.49 | eps:  0.406 | loss~:  1.228
# dqn_trial04 | Ep  350 | avg100:  -20.89 | eps:  0.349 | loss~:  1.124
# dqn_trial04 | Ep  400 | avg100:  -19.89 | eps:  0.301 | loss~:  1.135
# dqn_trial04 | Ep  450 | avg100:   -2.89 | eps:  0.259 | loss~:  1.152
# dqn_trial04 | Ep  500 | avg100:   28.72 | eps:  0.223 | loss~:  1.079
# dqn_trial04 | Ep  550 | avg100:   77.10 | eps:  0.192 | loss~:  0.993
# dqn_trial04 | Ep  600 | avg100:  147.24 | eps:  0.165 | loss~:  0.884
#
#  dqn_trial04 solved at ep 648 | avg100 201.17 | continue until ep 1148 | finetune_lr 3e-05
#
# dqn_trial04 | Ep  650 | avg100:  204.20 | eps:  0.142 | loss~:  0.878
# dqn_trial04 | Ep  700 | avg100:  227.76 | eps:  0.122 | loss~:  0.880
# dqn_trial04 | Ep  750 | avg100:  235.42 | eps:  0.105 | loss~:  0.844
# dqn_trial04 | Ep  800 | avg100:  237.10 | eps:  0.090 | loss~:  0.804
# dqn_trial04 | Ep  850 | avg100:  237.70 | eps:  0.078 | loss~:  0.730
# dqn_trial04 | Ep  900 | avg100:  240.78 | eps:  0.067 | loss~:  0.672
# dqn_trial04 | Ep  950 | avg100:  242.80 | eps:  0.058 | loss~:  0.650
# dqn_trial04 | Ep 1000 | avg100:  250.45 | eps:  0.050 | loss~:  0.601
# dqn_trial04 | Ep 1050 | avg100:  254.58 | eps:  0.043 | loss~:  0.569
# dqn_trial04 | Ep 1100 | avg100:  255.31 | eps:  0.037 | loss~:  0.605
# Trial 4 -> eval_mean: 255.78 ± 40.11 | BEST: 260.55
#
# === Trial 5/20 | cfg: {'lr': 0.0001, 'gamma': 0.99, 'lr_finetune': 3e-05, 'tau': 0.0005, 'batch_size': 128, 'buffer_size': 200000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial05 | Ep   50 | avg100: -170.70 | eps:  0.951 | loss~:  1.459
# dqn_trial05 | Ep  100 | avg100: -156.95 | eps:  0.905 | loss~:  1.321
# dqn_trial05 | Ep  150 | avg100: -144.29 | eps:  0.861 | loss~:  1.203
# dqn_trial05 | Ep  200 | avg100: -140.55 | eps:  0.819 | loss~:  1.080
# dqn_trial05 | Ep  250 | avg100: -129.54 | eps:  0.779 | loss~:  1.178
# dqn_trial05 | Ep  300 | avg100: -100.89 | eps:  0.741 | loss~:  1.228
# dqn_trial05 | Ep  350 | avg100:  -79.83 | eps:  0.705 | loss~:  1.209
# dqn_trial05 | Ep  400 | avg100:  -74.52 | eps:  0.670 | loss~:  1.137
# dqn_trial05 | Ep  450 | avg100:  -66.32 | eps:  0.637 | loss~:  1.117
# dqn_trial05 | Ep  500 | avg100:  -57.09 | eps:  0.606 | loss~:  1.096
# dqn_trial05 | Ep  550 | avg100:  -44.51 | eps:  0.577 | loss~:  1.183
# dqn_trial05 | Ep  600 | avg100:  -33.89 | eps:  0.549 | loss~:  1.212
# dqn_trial05 | Ep  650 | avg100:  -23.80 | eps:  0.522 | loss~:  1.274
# dqn_trial05 | Ep  700 | avg100:  -19.50 | eps:  0.496 | loss~:  1.322
# dqn_trial05 | Ep  750 | avg100:  -21.77 | eps:  0.472 | loss~:  1.282
# dqn_trial05 | Ep  800 | avg100:  -20.42 | eps:  0.449 | loss~:  1.428
# dqn_trial05 | Ep  850 | avg100:   -4.65 | eps:  0.427 | loss~:  1.482
# dqn_trial05 | Ep  900 | avg100:   16.29 | eps:  0.406 | loss~:  1.476
# dqn_trial05 | Ep  950 | avg100:   19.87 | eps:  0.387 | loss~:  1.548
# dqn_trial05 | Ep 1000 | avg100:   19.70 | eps:  0.368 | loss~:  1.411
# dqn_trial05 | Ep 1050 | avg100:   31.27 | eps:  0.350 | loss~:  1.513
# dqn_trial05 | Ep 1100 | avg100:   35.49 | eps:  0.333 | loss~:  1.484
# dqn_trial05 | Ep 1150 | avg100:   37.88 | eps:  0.316 | loss~:  1.447
# dqn_trial05 | Ep 1200 | avg100:   41.10 | eps:  0.301 | loss~:  1.448
# dqn_trial05 | Ep 1250 | avg100:   33.67 | eps:  0.286 | loss~:  1.444
# dqn_trial05 | Ep 1300 | avg100:   51.87 | eps:  0.272 | loss~:  1.301
# dqn_trial05 | Ep 1350 | avg100:   69.56 | eps:  0.259 | loss~:  1.236
# dqn_trial05 | Ep 1400 | avg100:   79.97 | eps:  0.246 | loss~:  1.237
# dqn_trial05 | Ep 1450 | avg100:  100.84 | eps:  0.234 | loss~:  1.160
# dqn_trial05 | Ep 1500 | avg100:  115.55 | eps:  0.223 | loss~:  1.207
# dqn_trial05 | Ep 1550 | avg100:  130.25 | eps:  0.212 | loss~:  1.294
# dqn_trial05 | Ep 1600 | avg100:  146.28 | eps:  0.202 | loss~:  1.147
# dqn_trial05 | Ep 1650 | avg100:  169.43 | eps:  0.192 | loss~:  1.225
# dqn_trial05 | Ep 1700 | avg100:  170.49 | eps:  0.183 | loss~:  1.165
# dqn_trial05 | Ep 1750 | avg100:  173.99 | eps:  0.174 | loss~:  1.059
# dqn_trial05 | Ep 1800 | avg100:  180.22 | eps:  0.165 | loss~:  0.945
# dqn_trial05 | Ep 1850 | avg100:  195.41 | eps:  0.157 | loss~:  0.983
#
#  dqn_trial05 solved at ep 1894 | avg100 202.91 | continue until ep 2394 | finetune_lr 3e-05
#
# dqn_trial05 | Ep 1900 | avg100:  200.48 | eps:  0.149 | loss~:  1.071
# dqn_trial05 | Ep 1950 | avg100:  193.96 | eps:  0.142 | loss~:  0.887
# dqn_trial05 | Ep 2000 | avg100:  212.70 | eps:  0.135 | loss~:  1.084
# dqn_trial05 | Ep 2050 | avg100:  226.52 | eps:  0.129 | loss~:  0.999
# dqn_trial05 | Ep 2100 | avg100:  235.66 | eps:  0.122 | loss~:  0.983
# dqn_trial05 | Ep 2150 | avg100:  230.02 | eps:  0.116 | loss~:  0.795
# dqn_trial05 | Ep 2200 | avg100:  234.72 | eps:  0.111 | loss~:  0.837
# dqn_trial05 | Ep 2250 | avg100:  228.99 | eps:  0.105 | loss~:  0.860
# dqn_trial05 | Ep 2300 | avg100:  212.72 | eps:  0.100 | loss~:  0.879
# dqn_trial05 | Ep 2350 | avg100:  239.49 | eps:  0.095 | loss~:  0.854
# Trial 5 -> eval_mean: 252.26 ± 43.43 | BEST: 260.55
#
# === Trial 6/20 | cfg: {'lr': 0.0001, 'gamma': 0.98, 'lr_finetune': 0.0001, 'tau': 0.002, 'batch_size': 64, 'buffer_size': 500000, 'learning_starts': 2000, 'update_every': 4, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 300, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial06 | Ep   50 | avg100: -165.31 | eps:  0.951 | loss~:  1.969
# dqn_trial06 | Ep  100 | avg100: -164.75 | eps:  0.905 | loss~:  1.703
# dqn_trial06 | Ep  150 | avg100: -153.06 | eps:  0.861 | loss~:  1.478
# dqn_trial06 | Ep  200 | avg100: -128.64 | eps:  0.819 | loss~:  1.528
# dqn_trial06 | Ep  250 | avg100: -111.73 | eps:  0.779 | loss~:  1.663
# dqn_trial06 | Ep  300 | avg100: -102.06 | eps:  0.741 | loss~:  1.486
# dqn_trial06 | Ep  350 | avg100:  -87.99 | eps:  0.705 | loss~:  1.615
# dqn_trial06 | Ep  400 | avg100:  -78.78 | eps:  0.670 | loss~:  1.551
# dqn_trial06 | Ep  450 | avg100:  -66.41 | eps:  0.637 | loss~:  1.600
# dqn_trial06 | Ep  500 | avg100:  -57.12 | eps:  0.606 | loss~:  1.575
# dqn_trial06 | Ep  550 | avg100:  -55.22 | eps:  0.577 | loss~:  1.473
# dqn_trial06 | Ep  600 | avg100:  -45.13 | eps:  0.549 | loss~:  1.309
# dqn_trial06 | Ep  650 | avg100:  -37.03 | eps:  0.522 | loss~:  1.268
# dqn_trial06 | Ep  700 | avg100:  -36.20 | eps:  0.496 | loss~:  1.631
# dqn_trial06 | Ep  750 | avg100:  -36.76 | eps:  0.472 | loss~:  1.516
# dqn_trial06 | Ep  800 | avg100:  -33.28 | eps:  0.449 | loss~:  1.823
# dqn_trial06 | Ep  850 | avg100:  -39.65 | eps:  0.427 | loss~:  1.904
# dqn_trial06 | Ep  900 | avg100:  -33.41 | eps:  0.406 | loss~:  1.825
# dqn_trial06 | Ep  950 | avg100:   -5.47 | eps:  0.387 | loss~:  1.980
# dqn_trial06 | Ep 1000 | avg100:   11.56 | eps:  0.368 | loss~:  1.977
# dqn_trial06 | Ep 1050 | avg100:   25.96 | eps:  0.350 | loss~:  1.989
# dqn_trial06 | Ep 1100 | avg100:   40.59 | eps:  0.333 | loss~:  1.905
# dqn_trial06 | Ep 1150 | avg100:   54.89 | eps:  0.316 | loss~:  1.877
# dqn_trial06 | Ep 1200 | avg100:   76.26 | eps:  0.301 | loss~:  1.867
# dqn_trial06 | Ep 1250 | avg100:   82.09 | eps:  0.286 | loss~:  1.714
# dqn_trial06 | Ep 1300 | avg100:   88.49 | eps:  0.272 | loss~:  1.765
# dqn_trial06 | Ep 1350 | avg100:  103.20 | eps:  0.259 | loss~:  1.696
# dqn_trial06 | Ep 1400 | avg100:  116.52 | eps:  0.246 | loss~:  1.504
# dqn_trial06 | Ep 1450 | avg100:  119.90 | eps:  0.234 | loss~:  1.433
# dqn_trial06 | Ep 1500 | avg100:  120.52 | eps:  0.223 | loss~:  1.386
# dqn_trial06 | Ep 1550 | avg100:  155.03 | eps:  0.212 | loss~:  1.291
# dqn_trial06 | Ep 1600 | avg100:  181.10 | eps:  0.202 | loss~:  1.027
#
#  dqn_trial06 solved at ep 1631 | avg100 200.39 | continue until ep 1931 | finetune_lr 0.0001
#
# dqn_trial06 | Ep 1650 | avg100:  196.81 | eps:  0.192 | loss~:  0.927
# dqn_trial06 | Ep 1700 | avg100:  204.52 | eps:  0.183 | loss~:  0.889
# dqn_trial06 | Ep 1750 | avg100:  195.62 | eps:  0.174 | loss~:  0.801
# dqn_trial06 | Ep 1800 | avg100:  185.86 | eps:  0.165 | loss~:  0.738
# dqn_trial06 | Ep 1850 | avg100:  189.79 | eps:  0.157 | loss~:  0.649
# dqn_trial06 | Ep 1900 | avg100:  201.98 | eps:  0.149 | loss~:  0.666
# Trial 6 -> eval_mean: 183.60 ± 86.40 | BEST: 260.55
#
# === Trial 7/20 | cfg: {'lr': 5e-05, 'gamma': 0.98, 'lr_finetune': 3e-05, 'tau': 0.001, 'batch_size': 64, 'buffer_size': 500000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.01, 'extra_after_solved': 300, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial07 | Ep   50 | avg100: -193.65 | eps:  0.951 | loss~:  1.655
# dqn_trial07 | Ep  100 | avg100: -181.68 | eps:  0.905 | loss~:  1.371
# dqn_trial07 | Ep  150 | avg100: -150.62 | eps:  0.861 | loss~:  1.377
# dqn_trial07 | Ep  200 | avg100: -123.30 | eps:  0.819 | loss~:  1.351
# dqn_trial07 | Ep  250 | avg100: -101.01 | eps:  0.779 | loss~:  1.347
# dqn_trial07 | Ep  300 | avg100:  -82.95 | eps:  0.741 | loss~:  1.384
# dqn_trial07 | Ep  350 | avg100:  -78.06 | eps:  0.705 | loss~:  1.343
# dqn_trial07 | Ep  400 | avg100:  -74.53 | eps:  0.670 | loss~:  1.410
# dqn_trial07 | Ep  450 | avg100:  -61.73 | eps:  0.637 | loss~:  1.154
# dqn_trial07 | Ep  500 | avg100:  -51.37 | eps:  0.606 | loss~:  1.443
# dqn_trial07 | Ep  550 | avg100:  -46.41 | eps:  0.577 | loss~:  1.515
# dqn_trial07 | Ep  600 | avg100:  -41.81 | eps:  0.549 | loss~:  1.325
# dqn_trial07 | Ep  650 | avg100:  -39.96 | eps:  0.522 | loss~:  1.384
# dqn_trial07 | Ep  700 | avg100:  -32.69 | eps:  0.496 | loss~:  1.361
# dqn_trial07 | Ep  750 | avg100:  -28.22 | eps:  0.472 | loss~:  1.522
# dqn_trial07 | Ep  800 | avg100:  -24.36 | eps:  0.449 | loss~:  1.799
# dqn_trial07 | Ep  850 | avg100:  -21.74 | eps:  0.427 | loss~:  1.860
# dqn_trial07 | Ep  900 | avg100:  -21.32 | eps:  0.406 | loss~:  1.995
# dqn_trial07 | Ep  950 | avg100:  -19.06 | eps:  0.387 | loss~:  1.872
# dqn_trial07 | Ep 1000 | avg100:  -15.13 | eps:  0.368 | loss~:  1.991
# dqn_trial07 | Ep 1050 | avg100:   -5.67 | eps:  0.350 | loss~:  2.234
# dqn_trial07 | Ep 1100 | avg100:   13.58 | eps:  0.333 | loss~:  2.063
# dqn_trial07 | Ep 1150 | avg100:   29.78 | eps:  0.316 | loss~:  2.073
# dqn_trial07 | Ep 1200 | avg100:   38.52 | eps:  0.301 | loss~:  2.062
# dqn_trial07 | Ep 1250 | avg100:   62.74 | eps:  0.286 | loss~:  1.945
# dqn_trial07 | Ep 1300 | avg100:   61.30 | eps:  0.272 | loss~:  1.939
# dqn_trial07 | Ep 1350 | avg100:   61.93 | eps:  0.259 | loss~:  2.042
# dqn_trial07 | Ep 1400 | avg100:   89.86 | eps:  0.246 | loss~:  1.786
# dqn_trial07 | Ep 1450 | avg100:  102.07 | eps:  0.234 | loss~:  1.769
# dqn_trial07 | Ep 1500 | avg100:  113.54 | eps:  0.223 | loss~:  1.666
# dqn_trial07 | Ep 1550 | avg100:  105.17 | eps:  0.212 | loss~:  1.429
# dqn_trial07 | Ep 1600 | avg100:  119.74 | eps:  0.202 | loss~:  1.213
# dqn_trial07 | Ep 1650 | avg100:  171.50 | eps:  0.192 | loss~:  1.128
# dqn_trial07 | Ep 1700 | avg100:  196.97 | eps:  0.183 | loss~:  1.090
#
#  dqn_trial07 solved at ep 1703 | avg100 200.60 | continue until ep 2003 | finetune_lr 3e-05
#
# dqn_trial07 | Ep 1750 | avg100:  193.84 | eps:  0.174 | loss~:  1.015
# dqn_trial07 | Ep 1800 | avg100:  195.09 | eps:  0.165 | loss~:  0.884
# dqn_trial07 | Ep 1850 | avg100:  218.35 | eps:  0.157 | loss~:  0.852
# dqn_trial07 | Ep 1900 | avg100:  225.81 | eps:  0.149 | loss~:  0.855
# dqn_trial07 | Ep 1950 | avg100:  227.55 | eps:  0.142 | loss~:  0.784
# dqn_trial07 | Ep 2000 | avg100:  230.56 | eps:  0.135 | loss~:  0.769
# Trial 7 -> eval_mean: 219.80 ± 71.52 | BEST: 260.55
#
# === Trial 8/20 | cfg: {'lr': 0.0002, 'gamma': 0.995, 'lr_finetune': 1e-05, 'tau': 0.001, 'batch_size': 128, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 2, 'eps_decay': 0.995, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial08 | Ep   50 | avg100: -156.99 | eps:  0.778 | loss~:  1.472
# dqn_trial08 | Ep  100 | avg100: -130.94 | eps:  0.606 | loss~:  1.311
# dqn_trial08 | Ep  150 | avg100:  -80.63 | eps:  0.471 | loss~:  1.254
# dqn_trial08 | Ep  200 | avg100:  -42.57 | eps:  0.367 | loss~:  1.155
# dqn_trial08 | Ep  250 | avg100:  -11.95 | eps:  0.286 | loss~:  1.204
# dqn_trial08 | Ep  300 | avg100:   41.53 | eps:  0.222 | loss~:  1.063
# dqn_trial08 | Ep  350 | avg100:  116.59 | eps:  0.173 | loss~:  1.031
# dqn_trial08 | Ep  400 | avg100:  184.32 | eps:  0.135 | loss~:  1.040
#
#  dqn_trial08 solved at ep 409 | avg100 200.91 | continue until ep 909 | finetune_lr 1e-05
#
# dqn_trial08 | Ep  450 | avg100:  227.24 | eps:  0.105 | loss~:  0.869
# dqn_trial08 | Ep  500 | avg100:  248.28 | eps:  0.082 | loss~:  0.745
# dqn_trial08 | Ep  550 | avg100:  256.62 | eps:  0.063 | loss~:  0.707
# dqn_trial08 | Ep  600 | avg100:  259.54 | eps:  0.049 | loss~:  0.666
# dqn_trial08 | Ep  650 | avg100:  261.98 | eps:  0.038 | loss~:  0.643
# dqn_trial08 | Ep  700 | avg100:  263.37 | eps:  0.030 | loss~:  0.644
# dqn_trial08 | Ep  750 | avg100:  260.42 | eps:  0.023 | loss~:  0.659
# dqn_trial08 | Ep  800 | avg100:  256.38 | eps:  0.018 | loss~:  0.653
# dqn_trial08 | Ep  850 | avg100:  257.39 | eps:  0.014 | loss~:  0.689
# dqn_trial08 | Ep  900 | avg100:  260.66 | eps:  0.011 | loss~:  0.620
# Trial 8 -> eval_mean: 248.76 ± 53.09 | BEST: 260.55
#
# === Trial 9/20 | cfg: {'lr': 0.0001, 'gamma': 0.995, 'lr_finetune': 1e-05, 'tau': 0.001, 'batch_size': 64, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial09 | Ep   50 | avg100: -168.15 | eps:  0.951 | loss~:  1.970
# dqn_trial09 | Ep  100 | avg100: -152.90 | eps:  0.905 | loss~:  1.554
# dqn_trial09 | Ep  150 | avg100: -134.84 | eps:  0.861 | loss~:  1.337
# dqn_trial09 | Ep  200 | avg100: -144.55 | eps:  0.819 | loss~:  1.403
# dqn_trial09 | Ep  250 | avg100: -127.87 | eps:  0.779 | loss~:  1.425
# dqn_trial09 | Ep  300 | avg100:  -87.22 | eps:  0.741 | loss~:  1.386
# dqn_trial09 | Ep  350 | avg100:  -76.69 | eps:  0.705 | loss~:  1.431
# dqn_trial09 | Ep  400 | avg100:  -73.65 | eps:  0.670 | loss~:  1.409
# dqn_trial09 | Ep  450 | avg100:  -61.33 | eps:  0.637 | loss~:  1.643
# dqn_trial09 | Ep  500 | avg100:  -52.73 | eps:  0.606 | loss~:  1.737
# dqn_trial09 | Ep  550 | avg100:  -50.96 | eps:  0.577 | loss~:  1.619
# dqn_trial09 | Ep  600 | avg100:  -44.52 | eps:  0.549 | loss~:  1.856
# dqn_trial09 | Ep  650 | avg100:  -37.19 | eps:  0.522 | loss~:  1.810
# dqn_trial09 | Ep  700 | avg100:  -32.01 | eps:  0.496 | loss~:  1.639
# dqn_trial09 | Ep  750 | avg100:  -31.91 | eps:  0.472 | loss~:  1.818
# dqn_trial09 | Ep  800 | avg100:  -36.78 | eps:  0.449 | loss~:  1.815
# dqn_trial09 | Ep  850 | avg100:  -31.38 | eps:  0.427 | loss~:  1.882
# dqn_trial09 | Ep  900 | avg100:  -24.05 | eps:  0.406 | loss~:  2.082
# dqn_trial09 | Ep  950 | avg100:  -29.89 | eps:  0.387 | loss~:  2.196
# dqn_trial09 | Ep 1000 | avg100:  -31.61 | eps:  0.368 | loss~:  2.404
# dqn_trial09 | Ep 1050 | avg100:  -19.36 | eps:  0.350 | loss~:  2.559
# dqn_trial09 | Ep 1100 | avg100:    0.27 | eps:  0.333 | loss~:  2.391
# dqn_trial09 | Ep 1150 | avg100:    8.93 | eps:  0.316 | loss~:  2.756
# dqn_trial09 | Ep 1200 | avg100:   11.26 | eps:  0.301 | loss~:  2.097
# dqn_trial09 | Ep 1250 | avg100:   11.13 | eps:  0.286 | loss~:  2.092
# dqn_trial09 | Ep 1300 | avg100:   16.37 | eps:  0.272 | loss~:  1.709
# dqn_trial09 | Ep 1350 | avg100:   36.57 | eps:  0.259 | loss~:  1.851
# dqn_trial09 | Ep 1400 | avg100:   70.20 | eps:  0.246 | loss~:  1.780
# dqn_trial09 | Ep 1450 | avg100:  111.16 | eps:  0.234 | loss~:  1.628
# dqn_trial09 | Ep 1500 | avg100:  147.43 | eps:  0.223 | loss~:  1.380
# dqn_trial09 | Ep 1550 | avg100:  176.99 | eps:  0.212 | loss~:  1.186
# dqn_trial09 | Ep 1600 | avg100:  175.58 | eps:  0.202 | loss~:  0.845
# dqn_trial09 | Ep 1650 | avg100:  164.90 | eps:  0.192 | loss~:  0.675
# dqn_trial09 | Ep 1700 | avg100:  183.39 | eps:  0.183 | loss~:  0.669
#
#  dqn_trial09 solved at ep 1727 | avg100 200.64 | continue until ep 2227 | finetune_lr 1e-05
#
# dqn_trial09 | Ep 1750 | avg100:  221.25 | eps:  0.174 | loss~:  0.581
# dqn_trial09 | Ep 1800 | avg100:  243.67 | eps:  0.165 | loss~:  0.523
# dqn_trial09 | Ep 1850 | avg100:  250.68 | eps:  0.157 | loss~:  0.586
# dqn_trial09 | Ep 1900 | avg100:  254.08 | eps:  0.149 | loss~:  0.456
# dqn_trial09 | Ep 1950 | avg100:  250.42 | eps:  0.142 | loss~:  0.578
# dqn_trial09 | Ep 2000 | avg100:  245.25 | eps:  0.135 | loss~:  0.568
# dqn_trial09 | Ep 2050 | avg100:  249.03 | eps:  0.129 | loss~:  0.549
# dqn_trial09 | Ep 2100 | avg100:  251.51 | eps:  0.122 | loss~:  0.526
# dqn_trial09 | Ep 2150 | avg100:  251.18 | eps:  0.116 | loss~:  0.587
# dqn_trial09 | Ep 2200 | avg100:  259.63 | eps:  0.111 | loss~:  0.545
# Trial 9 -> eval_mean: 251.83 ± 47.82 | BEST: 260.55
#
# === Trial 10/20 | cfg: {'lr': 3e-05, 'gamma': 0.98, 'lr_finetune': 3e-05, 'tau': 0.002, 'batch_size': 128, 'buffer_size': 200000, 'learning_starts': 1000, 'update_every': 4, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial10 | Ep   50 | avg100: -192.96 | eps:  0.951 | loss~:  2.172
# dqn_trial10 | Ep  100 | avg100: -176.81 | eps:  0.905 | loss~:  1.870
# dqn_trial10 | Ep  150 | avg100: -160.79 | eps:  0.861 | loss~:  1.897
# dqn_trial10 | Ep  200 | avg100: -145.97 | eps:  0.819 | loss~:  1.645
# dqn_trial10 | Ep  250 | avg100: -127.05 | eps:  0.779 | loss~:  1.481
# dqn_trial10 | Ep  300 | avg100: -119.67 | eps:  0.741 | loss~:  1.554
# dqn_trial10 | Ep  350 | avg100: -107.65 | eps:  0.705 | loss~:  1.729
# dqn_trial10 | Ep  400 | avg100:  -90.19 | eps:  0.670 | loss~:  1.626
# dqn_trial10 | Ep  450 | avg100:  -73.92 | eps:  0.637 | loss~:  1.666
# dqn_trial10 | Ep  500 | avg100:  -58.01 | eps:  0.606 | loss~:  1.735
# dqn_trial10 | Ep  550 | avg100:  -46.73 | eps:  0.577 | loss~:  1.594
# dqn_trial10 | Ep  600 | avg100:  -43.81 | eps:  0.549 | loss~:  1.584
# dqn_trial10 | Ep  650 | avg100:  -37.71 | eps:  0.522 | loss~:  1.611
# dqn_trial10 | Ep  700 | avg100:  -32.72 | eps:  0.496 | loss~:  1.492
# dqn_trial10 | Ep  750 | avg100:  -31.78 | eps:  0.472 | loss~:  1.644
# dqn_trial10 | Ep  800 | avg100:  -19.41 | eps:  0.449 | loss~:  1.684
# dqn_trial10 | Ep  850 | avg100:   -9.46 | eps:  0.427 | loss~:  1.738
# dqn_trial10 | Ep  900 | avg100:    3.53 | eps:  0.406 | loss~:  1.821
# dqn_trial10 | Ep  950 | avg100:   14.10 | eps:  0.387 | loss~:  1.814
# dqn_trial10 | Ep 1000 | avg100:   14.56 | eps:  0.368 | loss~:  1.820
# dqn_trial10 | Ep 1050 | avg100:   27.14 | eps:  0.350 | loss~:  1.952
# dqn_trial10 | Ep 1100 | avg100:   36.16 | eps:  0.333 | loss~:  1.923
# dqn_trial10 | Ep 1150 | avg100:   40.72 | eps:  0.316 | loss~:  1.845
# dqn_trial10 | Ep 1200 | avg100:   41.53 | eps:  0.301 | loss~:  1.667
# dqn_trial10 | Ep 1250 | avg100:   55.54 | eps:  0.286 | loss~:  1.447
# dqn_trial10 | Ep 1300 | avg100:   65.89 | eps:  0.272 | loss~:  1.359
# dqn_trial10 | Ep 1350 | avg100:   77.15 | eps:  0.259 | loss~:  1.204
# dqn_trial10 | Ep 1400 | avg100:   94.61 | eps:  0.246 | loss~:  1.163
# dqn_trial10 | Ep 1450 | avg100:   85.57 | eps:  0.234 | loss~:  1.084
# dqn_trial10 | Ep 1500 | avg100:   91.96 | eps:  0.223 | loss~:  1.027
# dqn_trial10 | Ep 1550 | avg100:  111.23 | eps:  0.212 | loss~:  0.989
# dqn_trial10 | Ep 1600 | avg100:  113.83 | eps:  0.202 | loss~:  0.866
# dqn_trial10 | Ep 1650 | avg100:  128.34 | eps:  0.192 | loss~:  0.825
# dqn_trial10 | Ep 1700 | avg100:  144.40 | eps:  0.183 | loss~:  0.802
# dqn_trial10 | Ep 1750 | avg100:  148.92 | eps:  0.174 | loss~:  0.764
# dqn_trial10 | Ep 1800 | avg100:  158.01 | eps:  0.165 | loss~:  0.734
# dqn_trial10 | Ep 1850 | avg100:  160.08 | eps:  0.157 | loss~:  0.749
# dqn_trial10 | Ep 1900 | avg100:  170.02 | eps:  0.149 | loss~:  0.705
# dqn_trial10 | Ep 1950 | avg100:  176.60 | eps:  0.142 | loss~:  0.747
# dqn_trial10 | Ep 2000 | avg100:  179.75 | eps:  0.135 | loss~:  0.712
# dqn_trial10 | Ep 2050 | avg100:  186.96 | eps:  0.129 | loss~:  0.744
# dqn_trial10 | Ep 2100 | avg100:  186.20 | eps:  0.122 | loss~:  0.784
# dqn_trial10 | Ep 2150 | avg100:  196.18 | eps:  0.116 | loss~:  0.755
#
#  dqn_trial10 solved at ep 2152 | avg100 201.06 | continue until ep 2500 | finetune_lr 3e-05
#
# dqn_trial10 | Ep 2200 | avg100:  209.01 | eps:  0.111 | loss~:  0.721
# dqn_trial10 | Ep 2250 | avg100:  218.43 | eps:  0.105 | loss~:  0.764
# dqn_trial10 | Ep 2300 | avg100:  211.38 | eps:  0.100 | loss~:  0.731
# dqn_trial10 | Ep 2350 | avg100:  200.01 | eps:  0.095 | loss~:  0.767
# dqn_trial10 | Ep 2400 | avg100:  221.33 | eps:  0.091 | loss~:  0.757
# dqn_trial10 | Ep 2450 | avg100:  238.11 | eps:  0.086 | loss~:  0.754
# dqn_trial10 | Ep 2500 | avg100:  232.70 | eps:  0.082 | loss~:  0.695
# Trial 10 -> eval_mean: 217.30 ± 45.55 | BEST: 260.55
#
# === Trial 11/20 | cfg: {'lr': 3e-05, 'gamma': 0.995, 'lr_finetune': 3e-05, 'tau': 0.002, 'batch_size': 64, 'buffer_size': 500000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.995, 'eps_min': 0.01, 'extra_after_solved': 300, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial11 | Ep   50 | avg100: -188.75 | eps:  0.778 | loss~:  2.007
# dqn_trial11 | Ep  100 | avg100: -154.08 | eps:  0.606 | loss~:  1.789
# dqn_trial11 | Ep  150 | avg100:  -87.54 | eps:  0.471 | loss~:  1.794
# dqn_trial11 | Ep  200 | avg100:  -36.46 | eps:  0.367 | loss~:  1.539
# dqn_trial11 | Ep  250 | avg100:   -1.22 | eps:  0.286 | loss~:  1.485
# dqn_trial11 | Ep  300 | avg100:   28.60 | eps:  0.222 | loss~:  1.313
# dqn_trial11 | Ep  350 | avg100:   25.33 | eps:  0.173 | loss~:  1.415
# dqn_trial11 | Ep  400 | avg100:   23.28 | eps:  0.135 | loss~:  1.169
# dqn_trial11 | Ep  450 | avg100:   35.55 | eps:  0.105 | loss~:  1.205
# dqn_trial11 | Ep  500 | avg100:   46.55 | eps:  0.082 | loss~:  1.203
# dqn_trial11 | Ep  550 | avg100:   88.19 | eps:  0.063 | loss~:  1.200
# dqn_trial11 | Ep  600 | avg100:  112.63 | eps:  0.049 | loss~:  1.103
# dqn_trial11 | Ep  650 | avg100:  114.26 | eps:  0.038 | loss~:  0.957
# dqn_trial11 | Ep  700 | avg100:  139.76 | eps:  0.030 | loss~:  1.090
# dqn_trial11 | Ep  750 | avg100:  153.59 | eps:  0.023 | loss~:  1.301
# dqn_trial11 | Ep  800 | avg100:  160.89 | eps:  0.018 | loss~:  1.455
# dqn_trial11 | Ep  850 | avg100:   49.55 | eps:  0.014 | loss~:  0.884
# dqn_trial11 | Ep  900 | avg100:  -60.37 | eps:  0.011 | loss~:  0.735
# dqn_trial11 | Ep  950 | avg100:  -15.35 | eps:  0.010 | loss~:  0.583
# dqn_trial11 | Ep 1000 | avg100:   46.58 | eps:  0.010 | loss~:  0.530
# dqn_trial11 | Ep 1050 | avg100:  106.08 | eps:  0.010 | loss~:  0.582
# dqn_trial11 | Ep 1100 | avg100:   86.92 | eps:  0.010 | loss~:  0.587
# dqn_trial11 | Ep 1150 | avg100:   67.66 | eps:  0.010 | loss~:  0.643
# dqn_trial11 | Ep 1200 | avg100:  114.49 | eps:  0.010 | loss~:  0.617
# dqn_trial11 | Ep 1250 | avg100:  103.38 | eps:  0.010 | loss~:  0.568
# dqn_trial11 | Ep 1300 | avg100:   55.33 | eps:  0.010 | loss~:  0.539
# dqn_trial11 | Ep 1350 | avg100:   47.74 | eps:  0.010 | loss~:  0.408
# dqn_trial11 | Ep 1400 | avg100:   44.69 | eps:  0.010 | loss~:  0.308
# dqn_trial11 | Ep 1450 | avg100:   28.53 | eps:  0.010 | loss~:  0.292
# dqn_trial11 | Ep 1500 | avg100:   74.67 | eps:  0.010 | loss~:  0.323
# dqn_trial11 | Ep 1550 | avg100:  153.86 | eps:  0.010 | loss~:  0.269
# dqn_trial11 | Ep 1600 | avg100:  164.43 | eps:  0.010 | loss~:  0.320
# dqn_trial11 | Ep 1650 | avg100:  177.60 | eps:  0.010 | loss~:  0.376
#
#  dqn_trial11 solved at ep 1679 | avg100 200.72 | continue until ep 1979 | finetune_lr 3e-05
#
# dqn_trial11 | Ep 1700 | avg100:  212.48 | eps:  0.010 | loss~:  0.329
# dqn_trial11 | Ep 1750 | avg100:  208.21 | eps:  0.010 | loss~:  0.327
# dqn_trial11 | Ep 1800 | avg100:  196.53 | eps:  0.010 | loss~:  0.395
# dqn_trial11 | Ep 1850 | avg100:  186.54 | eps:  0.010 | loss~:  0.416
# dqn_trial11 | Ep 1900 | avg100:  184.57 | eps:  0.010 | loss~:  0.521
# dqn_trial11 | Ep 1950 | avg100:  184.14 | eps:  0.010 | loss~:  0.394
# Trial 11 -> eval_mean: 194.82 ± 94.41 | BEST: 260.55
#
# === Trial 12/20 | cfg: {'lr': 0.0003, 'gamma': 0.98, 'lr_finetune': 3e-05, 'tau': 0.001, 'batch_size': 256, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 4, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial12 | Ep   50 | avg100: -150.05 | eps:  0.951 | loss~:  1.675
# dqn_trial12 | Ep  100 | avg100: -151.37 | eps:  0.905 | loss~:  1.487
# dqn_trial12 | Ep  150 | avg100: -150.66 | eps:  0.861 | loss~:  1.374
# dqn_trial12 | Ep  200 | avg100: -142.14 | eps:  0.819 | loss~:  1.388
# dqn_trial12 | Ep  250 | avg100: -130.56 | eps:  0.779 | loss~:  1.244
# dqn_trial12 | Ep  300 | avg100: -109.18 | eps:  0.741 | loss~:  1.291
# dqn_trial12 | Ep  350 | avg100:  -90.42 | eps:  0.705 | loss~:  1.282
# dqn_trial12 | Ep  400 | avg100:  -77.19 | eps:  0.670 | loss~:  1.418
# dqn_trial12 | Ep  450 | avg100:  -66.09 | eps:  0.637 | loss~:  1.366
# dqn_trial12 | Ep  500 | avg100:  -63.30 | eps:  0.606 | loss~:  1.309
# dqn_trial12 | Ep  550 | avg100:  -51.15 | eps:  0.577 | loss~:  1.236
# dqn_trial12 | Ep  600 | avg100:  -39.57 | eps:  0.549 | loss~:  1.238
# dqn_trial12 | Ep  650 | avg100:  -33.61 | eps:  0.522 | loss~:  1.405
# dqn_trial12 | Ep  700 | avg100:  -34.78 | eps:  0.496 | loss~:  1.361
# dqn_trial12 | Ep  750 | avg100:  -34.05 | eps:  0.472 | loss~:  1.346
# dqn_trial12 | Ep  800 | avg100:  -23.62 | eps:  0.449 | loss~:  1.377
# dqn_trial12 | Ep  850 | avg100:  -15.40 | eps:  0.427 | loss~:  1.348
# dqn_trial12 | Ep  900 | avg100:   -2.29 | eps:  0.406 | loss~:  1.427
# dqn_trial12 | Ep  950 | avg100:   22.52 | eps:  0.387 | loss~:  1.354
# dqn_trial12 | Ep 1000 | avg100:   30.84 | eps:  0.368 | loss~:  1.402
# dqn_trial12 | Ep 1050 | avg100:   32.15 | eps:  0.350 | loss~:  1.383
# dqn_trial12 | Ep 1100 | avg100:   35.17 | eps:  0.333 | loss~:  1.441
# dqn_trial12 | Ep 1150 | avg100:   46.81 | eps:  0.316 | loss~:  1.352
# dqn_trial12 | Ep 1200 | avg100:   64.99 | eps:  0.301 | loss~:  1.308
# dqn_trial12 | Ep 1250 | avg100:   68.91 | eps:  0.286 | loss~:  1.248
# dqn_trial12 | Ep 1300 | avg100:   70.51 | eps:  0.272 | loss~:  1.101
# dqn_trial12 | Ep 1350 | avg100:   73.42 | eps:  0.259 | loss~:  1.131
# dqn_trial12 | Ep 1400 | avg100:   96.55 | eps:  0.246 | loss~:  1.005
# dqn_trial12 | Ep 1450 | avg100:  119.42 | eps:  0.234 | loss~:  0.935
# dqn_trial12 | Ep 1500 | avg100:  125.40 | eps:  0.223 | loss~:  0.881
# dqn_trial12 | Ep 1550 | avg100:  121.03 | eps:  0.212 | loss~:  0.821
# dqn_trial12 | Ep 1600 | avg100:  125.75 | eps:  0.202 | loss~:  0.668
# dqn_trial12 | Ep 1650 | avg100:  141.07 | eps:  0.192 | loss~:  0.659
# dqn_trial12 | Ep 1700 | avg100:  163.35 | eps:  0.183 | loss~:  0.680
# dqn_trial12 | Ep 1750 | avg100:  162.79 | eps:  0.174 | loss~:  0.634
# dqn_trial12 | Ep 1800 | avg100:  168.58 | eps:  0.165 | loss~:  0.622
# dqn_trial12 | Ep 1850 | avg100:  191.42 | eps:  0.157 | loss~:  0.605
# dqn_trial12 | Ep 1900 | avg100:  179.92 | eps:  0.149 | loss~:  0.625
# dqn_trial12 | Ep 1950 | avg100:  180.32 | eps:  0.142 | loss~:  0.621
# dqn_trial12 | Ep 2000 | avg100:  201.20 | eps:  0.135 | loss~:  0.653
#
#  dqn_trial12 solved at ep 2000 | avg100 201.20 | continue until ep 2500 | finetune_lr 3e-05
#
# dqn_trial12 | Ep 2050 | avg100:  218.99 | eps:  0.129 | loss~:  0.567
# dqn_trial12 | Ep 2100 | avg100:  221.01 | eps:  0.122 | loss~:  0.674
# dqn_trial12 | Ep 2150 | avg100:  204.96 | eps:  0.116 | loss~:  0.674
# dqn_trial12 | Ep 2200 | avg100:  210.30 | eps:  0.111 | loss~:  0.646
# dqn_trial12 | Ep 2250 | avg100:  224.03 | eps:  0.105 | loss~:  0.655
# dqn_trial12 | Ep 2300 | avg100:  221.22 | eps:  0.100 | loss~:  0.723
# dqn_trial12 | Ep 2350 | avg100:  232.31 | eps:  0.095 | loss~:  0.696
# dqn_trial12 | Ep 2400 | avg100:  230.55 | eps:  0.091 | loss~:  0.731
# dqn_trial12 | Ep 2450 | avg100:  215.31 | eps:  0.086 | loss~:  0.789
# dqn_trial12 | Ep 2500 | avg100:  209.85 | eps:  0.082 | loss~:  0.724
# Trial 12 -> eval_mean: 226.00 ± 60.62 | BEST: 260.55
#
# === Trial 13/20 | cfg: {'lr': 0.0003, 'gamma': 0.99, 'lr_finetune': 3e-05, 'tau': 0.002, 'batch_size': 256, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 4, 'eps_decay': 0.995, 'eps_min': 0.005, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial13 | Ep   50 | avg100: -162.63 | eps:  0.778 | loss~:  1.518
# dqn_trial13 | Ep  100 | avg100: -128.86 | eps:  0.606 | loss~:  1.254
# dqn_trial13 | Ep  150 | avg100:  -77.29 | eps:  0.471 | loss~:  1.133
# dqn_trial13 | Ep  200 | avg100:  -36.76 | eps:  0.367 | loss~:  1.124
# dqn_trial13 | Ep  250 | avg100:   16.96 | eps:  0.286 | loss~:  0.944
# dqn_trial13 | Ep  300 | avg100:   89.00 | eps:  0.222 | loss~:  0.815
# dqn_trial13 | Ep  350 | avg100:  152.42 | eps:  0.173 | loss~:  0.849
#
#  dqn_trial13 solved at ep 398 | avg100 200.56 | continue until ep 898 | finetune_lr 3e-05
#
# dqn_trial13 | Ep  400 | avg100:  201.64 | eps:  0.135 | loss~:  0.803
# dqn_trial13 | Ep  450 | avg100:  239.68 | eps:  0.105 | loss~:  0.641
# dqn_trial13 | Ep  500 | avg100:  244.98 | eps:  0.082 | loss~:  0.596
# dqn_trial13 | Ep  550 | avg100:  233.27 | eps:  0.063 | loss~:  0.579
# dqn_trial13 | Ep  600 | avg100:  235.33 | eps:  0.049 | loss~:  0.577
# dqn_trial13 | Ep  650 | avg100:  233.46 | eps:  0.038 | loss~:  0.571
# dqn_trial13 | Ep  700 | avg100:  230.55 | eps:  0.030 | loss~:  0.569
# dqn_trial13 | Ep  750 | avg100:  227.12 | eps:  0.023 | loss~:  0.588
# dqn_trial13 | Ep  800 | avg100:  212.47 | eps:  0.018 | loss~:  0.601
# dqn_trial13 | Ep  850 | avg100:  214.92 | eps:  0.014 | loss~:  0.617
# Trial 13 -> eval_mean: 259.15 ± 42.35 | BEST: 260.55
#
# === Trial 14/20 | cfg: {'lr': 3e-05, 'gamma': 0.99, 'lr_finetune': 1e-05, 'tau': 0.001, 'batch_size': 64, 'buffer_size': 500000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 300, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial14 | Ep   50 | avg100: -193.11 | eps:  0.951 | loss~:  1.825
# dqn_trial14 | Ep  100 | avg100: -169.60 | eps:  0.905 | loss~:  1.752
# dqn_trial14 | Ep  150 | avg100: -136.54 | eps:  0.861 | loss~:  1.600
# dqn_trial14 | Ep  200 | avg100: -126.94 | eps:  0.819 | loss~:  1.448
# dqn_trial14 | Ep  250 | avg100: -120.48 | eps:  0.779 | loss~:  1.344
# dqn_trial14 | Ep  300 | avg100: -105.59 | eps:  0.741 | loss~:  1.415
# dqn_trial14 | Ep  350 | avg100:  -89.36 | eps:  0.705 | loss~:  1.453
# dqn_trial14 | Ep  400 | avg100:  -77.32 | eps:  0.670 | loss~:  1.590
# dqn_trial14 | Ep  450 | avg100:  -64.80 | eps:  0.637 | loss~:  1.456
# dqn_trial14 | Ep  500 | avg100:  -58.66 | eps:  0.606 | loss~:  1.405
# dqn_trial14 | Ep  550 | avg100:  -53.57 | eps:  0.577 | loss~:  1.364
# dqn_trial14 | Ep  600 | avg100:  -43.23 | eps:  0.549 | loss~:  1.394
# dqn_trial14 | Ep  650 | avg100:  -33.83 | eps:  0.522 | loss~:  1.502
# dqn_trial14 | Ep  700 | avg100:  -28.91 | eps:  0.496 | loss~:  1.627
# dqn_trial14 | Ep  750 | avg100:  -27.16 | eps:  0.472 | loss~:  1.742
# dqn_trial14 | Ep  800 | avg100:  -19.31 | eps:  0.449 | loss~:  1.741
# dqn_trial14 | Ep  850 | avg100:  -18.88 | eps:  0.427 | loss~:  1.899
# dqn_trial14 | Ep  900 | avg100:  -18.82 | eps:  0.406 | loss~:  2.325
# dqn_trial14 | Ep  950 | avg100:  -18.83 | eps:  0.387 | loss~:  2.527
# dqn_trial14 | Ep 1000 | avg100:  -24.14 | eps:  0.368 | loss~:  2.733
# dqn_trial14 | Ep 1050 | avg100:  -19.31 | eps:  0.350 | loss~:  2.728
# dqn_trial14 | Ep 1100 | avg100:  -14.56 | eps:  0.333 | loss~:  2.744
# dqn_trial14 | Ep 1150 | avg100:    0.48 | eps:  0.316 | loss~:  2.647
# dqn_trial14 | Ep 1200 | avg100:   28.39 | eps:  0.301 | loss~:  2.792
# dqn_trial14 | Ep 1250 | avg100:   49.85 | eps:  0.286 | loss~:  2.892
# dqn_trial14 | Ep 1300 | avg100:   62.32 | eps:  0.272 | loss~:  2.880
# dqn_trial14 | Ep 1350 | avg100:   67.17 | eps:  0.259 | loss~:  2.751
# dqn_trial14 | Ep 1400 | avg100:   75.64 | eps:  0.246 | loss~:  2.472
# dqn_trial14 | Ep 1450 | avg100:   84.23 | eps:  0.234 | loss~:  2.779
# dqn_trial14 | Ep 1500 | avg100:   99.12 | eps:  0.223 | loss~:  2.442
# dqn_trial14 | Ep 1550 | avg100:  116.54 | eps:  0.212 | loss~:  2.374
# dqn_trial14 | Ep 1600 | avg100:  147.82 | eps:  0.202 | loss~:  1.994
# dqn_trial14 | Ep 1650 | avg100:  180.36 | eps:  0.192 | loss~:  1.859
# dqn_trial14 | Ep 1700 | avg100:  188.06 | eps:  0.183 | loss~:  1.705
# dqn_trial14 | Ep 1750 | avg100:  191.06 | eps:  0.174 | loss~:  1.575
#
#  dqn_trial14 solved at ep 1769 | avg100 200.07 | continue until ep 2069 | finetune_lr 1e-05
#
# dqn_trial14 | Ep 1800 | avg100:  206.34 | eps:  0.165 | loss~:  1.490
# dqn_trial14 | Ep 1850 | avg100:  222.88 | eps:  0.157 | loss~:  1.326
# dqn_trial14 | Ep 1900 | avg100:  224.21 | eps:  0.149 | loss~:  1.328
# dqn_trial14 | Ep 1950 | avg100:  223.81 | eps:  0.142 | loss~:  1.349
# dqn_trial14 | Ep 2000 | avg100:  230.26 | eps:  0.135 | loss~:  1.388
# dqn_trial14 | Ep 2050 | avg100:  240.09 | eps:  0.129 | loss~:  1.269
# Trial 14 -> eval_mean: 230.83 ± 48.35 | BEST: 260.55
#
# === Trial 15/20 | cfg: {'lr': 0.0003, 'gamma': 0.995, 'lr_finetune': 0.0001, 'tau': 0.001, 'batch_size': 64, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 4, 'eps_decay': 0.995, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial15 | Ep   50 | avg100: -169.98 | eps:  0.778 | loss~:  1.592
# dqn_trial15 | Ep  100 | avg100: -146.66 | eps:  0.606 | loss~:  1.467
# dqn_trial15 | Ep  150 | avg100: -102.44 | eps:  0.471 | loss~:  1.283
# dqn_trial15 | Ep  200 | avg100:  -46.53 | eps:  0.367 | loss~:  1.309
# dqn_trial15 | Ep  250 | avg100:  -14.53 | eps:  0.286 | loss~:  0.935
# dqn_trial15 | Ep  300 | avg100:  -13.61 | eps:  0.222 | loss~:  0.700
# dqn_trial15 | Ep  350 | avg100:   40.54 | eps:  0.173 | loss~:  0.802
# dqn_trial15 | Ep  400 | avg100:  127.09 | eps:  0.135 | loss~:  0.659
# dqn_trial15 | Ep  450 | avg100:  189.72 | eps:  0.105 | loss~:  0.410
#
#  dqn_trial15 solved at ep 463 | avg100 200.43 | continue until ep 963 | finetune_lr 0.0001
#
# dqn_trial15 | Ep  500 | avg100:  229.28 | eps:  0.082 | loss~:  0.442
# dqn_trial15 | Ep  550 | avg100:  247.19 | eps:  0.063 | loss~:  0.446
# dqn_trial15 | Ep  600 | avg100:  255.00 | eps:  0.049 | loss~:  0.428
# dqn_trial15 | Ep  650 | avg100:  255.64 | eps:  0.038 | loss~:  0.467
# dqn_trial15 | Ep  700 | avg100:  253.18 | eps:  0.030 | loss~:  0.481
# dqn_trial15 | Ep  750 | avg100:  249.97 | eps:  0.023 | loss~:  0.400
# dqn_trial15 | Ep  800 | avg100:  249.75 | eps:  0.018 | loss~:  0.469
# dqn_trial15 | Ep  850 | avg100:  249.45 | eps:  0.014 | loss~:  0.431
# dqn_trial15 | Ep  900 | avg100:  251.38 | eps:  0.011 | loss~:  0.525
# dqn_trial15 | Ep  950 | avg100:  251.99 | eps:  0.010 | loss~:  0.517
# Trial 15 -> eval_mean: 232.72 ± 50.52 | BEST: 260.55
#
# === Trial 16/20 | cfg: {'lr': 3e-05, 'gamma': 0.995, 'lr_finetune': 1e-05, 'tau': 0.0005, 'batch_size': 128, 'buffer_size': 200000, 'learning_starts': 2000, 'update_every': 4, 'eps_decay': 0.995, 'eps_min': 0.01, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial16 | Ep   50 | avg100: -207.79 | eps:  0.778 | loss~:  2.229
# dqn_trial16 | Ep  100 | avg100: -176.11 | eps:  0.606 | loss~:  1.784
# dqn_trial16 | Ep  150 | avg100: -120.46 | eps:  0.471 | loss~:  1.560
# dqn_trial16 | Ep  200 | avg100:  -95.47 | eps:  0.367 | loss~:  1.395
# dqn_trial16 | Ep  250 | avg100:  -82.08 | eps:  0.286 | loss~:  1.278
# dqn_trial16 | Ep  300 | avg100:  -40.91 | eps:  0.222 | loss~:  1.050
# dqn_trial16 | Ep  350 | avg100:  -40.22 | eps:  0.173 | loss~:  0.942
# dqn_trial16 | Ep  400 | avg100:  -71.80 | eps:  0.135 | loss~:  0.834
# dqn_trial16 | Ep  450 | avg100:  -74.24 | eps:  0.105 | loss~:  0.554
# dqn_trial16 | Ep  500 | avg100:  -51.66 | eps:  0.082 | loss~:  0.314
# dqn_trial16 | Ep  550 | avg100:  -18.15 | eps:  0.063 | loss~:  0.239
# dqn_trial16 | Ep  600 | avg100:   15.54 | eps:  0.049 | loss~:  0.226
# dqn_trial16 | Ep  650 | avg100:   48.99 | eps:  0.038 | loss~:  0.218
# dqn_trial16 | Ep  700 | avg100:   64.45 | eps:  0.030 | loss~:  0.285
# dqn_trial16 | Ep  750 | avg100:   73.41 | eps:  0.023 | loss~:  0.270
# dqn_trial16 | Ep  800 | avg100:   76.76 | eps:  0.018 | loss~:  0.288
# dqn_trial16 | Ep  850 | avg100:   73.12 | eps:  0.014 | loss~:  0.299
# dqn_trial16 | Ep  900 | avg100:   81.58 | eps:  0.011 | loss~:  0.311
# dqn_trial16 | Ep  950 | avg100:   96.31 | eps:  0.010 | loss~:  0.341
# dqn_trial16 | Ep 1000 | avg100:   89.94 | eps:  0.010 | loss~:  0.327
# dqn_trial16 | Ep 1050 | avg100:   84.50 | eps:  0.010 | loss~:  0.285
# dqn_trial16 | Ep 1100 | avg100:  105.81 | eps:  0.010 | loss~:  0.333
# dqn_trial16 | Ep 1150 | avg100:  117.99 | eps:  0.010 | loss~:  0.335
# dqn_trial16 | Ep 1200 | avg100:  119.96 | eps:  0.010 | loss~:  0.363
# dqn_trial16 | Ep 1250 | avg100:  149.89 | eps:  0.010 | loss~:  0.425
# dqn_trial16 | Ep 1300 | avg100:  167.47 | eps:  0.010 | loss~:  0.476
# dqn_trial16 | Ep 1350 | avg100:  136.40 | eps:  0.010 | loss~:  0.534
# dqn_trial16 | Ep 1400 | avg100:  113.25 | eps:  0.010 | loss~:  0.580
# dqn_trial16 | Ep 1450 | avg100:  117.59 | eps:  0.010 | loss~:  0.644
# dqn_trial16 | Ep 1500 | avg100:  143.33 | eps:  0.010 | loss~:  0.647
# dqn_trial16 | Ep 1550 | avg100:  167.61 | eps:  0.010 | loss~:  0.685
# dqn_trial16 | Ep 1600 | avg100:  172.97 | eps:  0.010 | loss~:  0.743
# dqn_trial16 | Ep 1650 | avg100:  195.44 | eps:  0.010 | loss~:  0.680
#
#  dqn_trial16 solved at ep 1661 | avg100 200.36 | continue until ep 2161 | finetune_lr 1e-05
#
# dqn_trial16 | Ep 1700 | avg100:  215.28 | eps:  0.010 | loss~:  0.696
# dqn_trial16 | Ep 1750 | avg100:  227.69 | eps:  0.010 | loss~:  0.747
# dqn_trial16 | Ep 1800 | avg100:  240.01 | eps:  0.010 | loss~:  0.745
# dqn_trial16 | Ep 1850 | avg100:  241.72 | eps:  0.010 | loss~:  0.704
# dqn_trial16 | Ep 1900 | avg100:  234.54 | eps:  0.010 | loss~:  0.736
# dqn_trial16 | Ep 1950 | avg100:  221.36 | eps:  0.010 | loss~:  0.725
# dqn_trial16 | Ep 2000 | avg100:  212.63 | eps:  0.010 | loss~:  0.643
# dqn_trial16 | Ep 2050 | avg100:  183.22 | eps:  0.010 | loss~:  0.483
# dqn_trial16 | Ep 2100 | avg100:  134.14 | eps:  0.010 | loss~:  0.457
# dqn_trial16 | Ep 2150 | avg100:  111.53 | eps:  0.010 | loss~:  0.327
# Trial 16 -> eval_mean: 132.87 ± 60.11 | BEST: 260.55
#
# === Trial 17/20 | cfg: {'lr': 3e-05, 'gamma': 0.99, 'lr_finetune': 3e-05, 'tau': 0.0005, 'batch_size': 256, 'buffer_size': 500000, 'learning_starts': 2000, 'update_every': 4, 'eps_decay': 0.995, 'eps_min': 0.01, 'extra_after_solved': 300, 'eval_episodes': 20, 'make_gif': False} ===
# dqn_trial17 | Ep   50 | avg100: -193.89 | eps:  0.778 | loss~:  2.221
# dqn_trial17 | Ep  100 | avg100: -163.42 | eps:  0.606 | loss~:  1.753
# ...
# dqn_trial20 | Ep  200 | avg100:  -71.73 | eps:  0.548 | loss~:  1.352
# dqn_trial20 | Ep  250 | avg100:  -41.21 | eps:  0.472 | loss~:  1.362
# dqn_trial20 | Ep  300 | avg100:  -11.66 | eps:  0.406 | loss~:  1.382
# dqn_trial20 | Ep  350 | avg100:    7.37 | eps:  0.349 | loss~:  1.400
# dqn_trial20 | Ep  400 | avg100:   17.99 | eps:  0.301 | loss~:  1.468
# dqn_trial20 | Ep  450 | avg100:   52.44 | eps:  0.259 | loss~:  1.410
# dqn_trial20 | Ep  500 | avg100:  100.03 | eps:  0.223 | loss~:  1.326
# dqn_trial20 | Ep  550 | avg100:  118.21 | eps:  0.192 | loss~:  1.234
# dqn_trial20 | Ep  600 | avg100:  143.06 | eps:  0.165 | loss~:  1.206
# dqn_trial20 | Ep  650 | avg100:  163.92 | eps:  0.142 | loss~:  1.054
# dqn_trial20 | Ep  700 | avg100:  172.72 | eps:  0.122 | loss~:  0.993
# dqn_trial20 | Ep  750 | avg100:  193.68 | eps:  0.105 | loss~:  1.050
#
#  dqn_trial20 solved at ep 758 | avg100 200.44 | continue until ep 1058 | finetune_lr 3e-05
#
# dqn_trial20 | Ep  800 | avg100:  212.34 | eps:  0.090 | loss~:  1.005
# dqn_trial20 | Ep  850 | avg100:  228.96 | eps:  0.078 | loss~:  0.893
# dqn_trial20 | Ep  900 | avg100:  238.76 | eps:  0.067 | loss~:  0.860
# dqn_trial20 | Ep  950 | avg100:  248.61 | eps:  0.058 | loss~:  0.794
# dqn_trial20 | Ep 1000 | avg100:  243.10 | eps:  0.050 | loss~:  0.799
# dqn_trial20 | Ep 1050 | avg100:  229.21 | eps:  0.043 | loss~:  0.769
# Trial 20 -> eval_mean: 194.98 ± 108.89 | BEST: 260.55
#
# BEST CFG: {'lr': 0.0002, 'gamma': 0.99, 'lr_finetune': 0.0001, 'tau': 0.001, 'batch_size': 256, 'buffer_size': 500000, 'learning_starts': 1000, 'update_every': 2, 'eps_decay': 0.999, 'eps_min': 0.005, 'extra_after_solved': 500, 'eval_episodes': 20, 'make_gif': False, 'grad_clip': 10.0, 'eps_start': 1.0, 'total_episodes': 2500, 'max_steps': 1000, 'solved_avg100': 200.0, 'gif_tries': 1200, 'center_tol': 0.12}
#
# === FINAL seed 42 ===
# dqn_final | Ep   50 | avg100: -165.90 | eps:  0.951 | loss~:  1.491
# dqn_final | Ep  100 | avg100: -146.54 | eps:  0.905 | loss~:  1.263
# dqn_final | Ep  150 | avg100: -131.08 | eps:  0.861 | loss~:  1.223
# dqn_final | Ep  200 | avg100: -123.95 | eps:  0.819 | loss~:  1.151
# dqn_final | Ep  250 | avg100: -108.92 | eps:  0.779 | loss~:  1.210
# dqn_final | Ep  300 | avg100:  -93.89 | eps:  0.741 | loss~:  1.287
# dqn_final | Ep  350 | avg100:  -80.92 | eps:  0.705 | loss~:  1.282
# dqn_final | Ep  400 | avg100:  -76.32 | eps:  0.670 | loss~:  1.333
# dqn_final | Ep  450 | avg100:  -63.99 | eps:  0.637 | loss~:  1.379
# dqn_final | Ep  500 | avg100:  -54.28 | eps:  0.606 | loss~:  1.534
# dqn_final | Ep  550 | avg100:  -47.21 | eps:  0.577 | loss~:  1.548
# dqn_final | Ep  600 | avg100:  -34.18 | eps:  0.549 | loss~:  1.698
# dqn_final | Ep  650 | avg100:  -29.06 | eps:  0.522 | loss~:  1.765
# dqn_final | Ep  700 | avg100:  -27.07 | eps:  0.496 | loss~:  1.838
# dqn_final | Ep  750 | avg100:  -19.17 | eps:  0.472 | loss~:  2.016
# dqn_final | Ep  800 | avg100:  -15.48 | eps:  0.449 | loss~:  2.291
# dqn_final | Ep  850 | avg100:  -13.00 | eps:  0.427 | loss~:  2.446
# dqn_final | Ep  900 | avg100:   -6.61 | eps:  0.406 | loss~:  2.737
# dqn_final | Ep  950 | avg100:   -4.09 | eps:  0.387 | loss~:  2.755
# dqn_final | Ep 1000 | avg100:    2.56 | eps:  0.368 | loss~:  2.810
# dqn_final | Ep 1050 | avg100:   16.67 | eps:  0.350 | loss~:  3.095
# dqn_final | Ep 1100 | avg100:   20.01 | eps:  0.333 | loss~:  2.906
# dqn_final | Ep 1150 | avg100:   18.83 | eps:  0.316 | loss~:  2.909
# dqn_final | Ep 1200 | avg100:   17.64 | eps:  0.301 | loss~:  2.920
# dqn_final | Ep 1250 | avg100:   20.49 | eps:  0.286 | loss~:  2.708
# dqn_final | Ep 1300 | avg100:   31.22 | eps:  0.272 | loss~:  2.439
# dqn_final | Ep 1350 | avg100:   36.64 | eps:  0.259 | loss~:  2.362
# dqn_final | Ep 1400 | avg100:   60.38 | eps:  0.246 | loss~:  2.396
# dqn_final | Ep 1450 | avg100:   69.33 | eps:  0.234 | loss~:  2.554
# dqn_final | Ep 1500 | avg100:   91.17 | eps:  0.223 | loss~:  2.189
# dqn_final | Ep 1550 | avg100:  138.45 | eps:  0.212 | loss~:  1.899
# dqn_final | Ep 1600 | avg100:  151.31 | eps:  0.202 | loss~:  1.789
# dqn_final | Ep 1650 | avg100:  145.94 | eps:  0.192 | loss~:  1.625
# dqn_final | Ep 1700 | avg100:  159.78 | eps:  0.183 | loss~:  1.963
# dqn_final | Ep 1750 | avg100:  172.50 | eps:  0.174 | loss~:  1.396
# dqn_final | Ep 1800 | avg100:  169.10 | eps:  0.165 | loss~:  1.213
# dqn_final | Ep 1850 | avg100:  193.48 | eps:  0.157 | loss~:  0.977
#
#  dqn_final solved at ep 1865 | avg100 201.23 | continue until ep 2365 | finetune_lr 0.0001
#
# dqn_final | Ep 1900 | avg100:  222.36 | eps:  0.149 | loss~:  0.859
# dqn_final | Ep 1950 | avg100:  224.05 | eps:  0.142 | loss~:  0.834
# dqn_final | Ep 2000 | avg100:  225.37 | eps:  0.135 | loss~:  0.746
# dqn_final | Ep 2050 | avg100:  218.17 | eps:  0.129 | loss~:  0.760
# dqn_final | Ep 2100 | avg100:  203.02 | eps:  0.122 | loss~:  0.658
# dqn_final | Ep 2150 | avg100:  196.37 | eps:  0.116 | loss~:  0.633
# dqn_final | Ep 2200 | avg100:  208.90 | eps:  0.111 | loss~:  0.619
# dqn_final | Ep 2250 | avg100:  224.88 | eps:  0.105 | loss~:  0.599
# dqn_final | Ep 2300 | avg100:  219.83 | eps:  0.100 | loss~:  0.552
# dqn_final | Ep 2350 | avg100:  229.13 | eps:  0.095 | loss~:  0.562
#
# === FINAL seed 123 ===
# dqn_final | Ep   50 | avg100: -183.57 | eps:  0.951 | loss~:  1.265
# dqn_final | Ep  100 | avg100: -169.74 | eps:  0.905 | loss~:  1.301
# dqn_final | Ep  150 | avg100: -143.04 | eps:  0.861 | loss~:  1.294
# dqn_final | Ep  200 | avg100: -117.08 | eps:  0.819 | loss~:  1.228
# dqn_final | Ep  250 | avg100: -101.43 | eps:  0.779 | loss~:  1.272
# dqn_final | Ep  300 | avg100:  -88.75 | eps:  0.741 | loss~:  1.233
# dqn_final | Ep  350 | avg100:  -75.47 | eps:  0.705 | loss~:  1.241
# dqn_final | Ep  400 | avg100:  -68.24 | eps:  0.670 | loss~:  1.273
# dqn_final | Ep  450 | avg100:  -60.94 | eps:  0.637 | loss~:  1.233
# dqn_final | Ep  500 | avg100:  -50.73 | eps:  0.606 | loss~:  1.331
# dqn_final | Ep  550 | avg100:  -45.66 | eps:  0.577 | loss~:  1.352
# dqn_final | Ep  600 | avg100:  -46.29 | eps:  0.549 | loss~:  1.450
# dqn_final | Ep  650 | avg100:  -36.01 | eps:  0.522 | loss~:  1.466
# dqn_final | Ep  700 | avg100:  -24.42 | eps:  0.496 | loss~:  1.629
# dqn_final | Ep  750 | avg100:  -27.34 | eps:  0.472 | loss~:  1.796
# dqn_final | Ep  800 | avg100:  -35.26 | eps:  0.449 | loss~:  1.909
# dqn_final | Ep  850 | avg100:  -30.15 | eps:  0.427 | loss~:  1.963
# dqn_final | Ep  900 | avg100:  -21.94 | eps:  0.406 | loss~:  1.971
# dqn_final | Ep  950 | avg100:  -12.38 | eps:  0.387 | loss~:  2.122
# dqn_final | Ep 1000 | avg100:    1.89 | eps:  0.368 | loss~:  2.125
# dqn_final | Ep 1050 | avg100:    6.30 | eps:  0.350 | loss~:  2.266
# dqn_final | Ep 1100 | avg100:    4.45 | eps:  0.333 | loss~:  2.369
# dqn_final | Ep 1150 | avg100:   18.59 | eps:  0.316 | loss~:  2.347
# dqn_final | Ep 1200 | avg100:   34.70 | eps:  0.301 | loss~:  2.393
# dqn_final | Ep 1250 | avg100:   38.84 | eps:  0.286 | loss~:  2.485
# dqn_final | Ep 1300 | avg100:   46.49 | eps:  0.272 | loss~:  2.396
# dqn_final | Ep 1350 | avg100:   38.24 | eps:  0.259 | loss~:  2.403
# dqn_final | Ep 1400 | avg100:   51.26 | eps:  0.246 | loss~:  2.347
# dqn_final | Ep 1450 | avg100:   80.66 | eps:  0.234 | loss~:  2.078
# dqn_final | Ep 1500 | avg100:   92.83 | eps:  0.223 | loss~:  1.945
# dqn_final | Ep 1550 | avg100:  114.68 | eps:  0.212 | loss~:  1.746
# dqn_final | Ep 1600 | avg100:  112.88 | eps:  0.202 | loss~:  1.787
# dqn_final | Ep 1650 | avg100:  114.40 | eps:  0.192 | loss~:  1.694
# dqn_final | Ep 1700 | avg100:  152.78 | eps:  0.183 | loss~:  1.749
# dqn_final | Ep 1750 | avg100:  170.21 | eps:  0.174 | loss~:  1.444
# dqn_final | Ep 1800 | avg100:  176.25 | eps:  0.165 | loss~:  1.486
# dqn_final | Ep 1850 | avg100:  156.30 | eps:  0.157 | loss~:  1.347
# dqn_final | Ep 1900 | avg100:  153.34 | eps:  0.149 | loss~:  1.224
# dqn_final | Ep 1950 | avg100:  188.09 | eps:  0.142 | loss~:  1.193
# dqn_final | Ep 2000 | avg100:  179.41 | eps:  0.135 | loss~:  1.098
# dqn_final | Ep 2050 | avg100:  148.48 | eps:  0.129 | loss~:  1.026
# dqn_final | Ep 2100 | avg100:  126.94 | eps:  0.122 | loss~:  1.007
# dqn_final | Ep 2150 | avg100:  121.39 | eps:  0.116 | loss~:  0.903
# dqn_final | Ep 2200 | avg100:  147.54 | eps:  0.111 | loss~:  0.920
# dqn_final | Ep 2250 | avg100:  189.56 | eps:  0.105 | loss~:  0.858
#
#  dqn_final solved at ep 2277 | avg100 201.40 | continue until ep 2500 | finetune_lr 0.0001
#
# dqn_final | Ep 2300 | avg100:  218.13 | eps:  0.100 | loss~:  0.760
# dqn_final | Ep 2350 | avg100:  210.30 | eps:  0.095 | loss~:  0.765
# dqn_final | Ep 2400 | avg100:  211.52 | eps:  0.091 | loss~:  0.754
# dqn_final | Ep 2450 | avg100:  243.16 | eps:  0.086 | loss~:  0.793
# dqn_final | Ep 2500 | avg100:  244.51 | eps:  0.082 | loss~:  0.686
#
# === FINAL seed 999 ===
# dqn_final | Ep   50 | avg100: -170.52 | eps:  0.951 | loss~:  1.433
# dqn_final | Ep  100 | avg100: -158.14 | eps:  0.905 | loss~:  1.362
# dqn_final | Ep  150 | avg100: -125.48 | eps:  0.861 | loss~:  1.386
# dqn_final | Ep  200 | avg100: -105.59 | eps:  0.819 | loss~:  1.272
# dqn_final | Ep  250 | avg100: -101.65 | eps:  0.779 | loss~:  1.309
# dqn_final | Ep  300 | avg100:  -91.43 | eps:  0.741 | loss~:  1.189
# dqn_final | Ep  350 | avg100:  -79.84 | eps:  0.705 | loss~:  1.291
# dqn_final | Ep  400 | avg100:  -66.90 | eps:  0.670 | loss~:  1.322
# dqn_final | Ep  450 | avg100:  -58.61 | eps:  0.637 | loss~:  1.421
# dqn_final | Ep  500 | avg100:  -51.48 | eps:  0.606 | loss~:  1.321
# dqn_final | Ep  550 | avg100:  -43.79 | eps:  0.577 | loss~:  1.291
# dqn_final | Ep  600 | avg100:  -40.05 | eps:  0.549 | loss~:  1.342
# dqn_final | Ep  650 | avg100:  -31.76 | eps:  0.522 | loss~:  1.345
# dqn_final | Ep  700 | avg100:  -23.68 | eps:  0.496 | loss~:  1.425
# dqn_final | Ep  750 | avg100:  -12.88 | eps:  0.472 | loss~:  1.524
# dqn_final | Ep  800 | avg100:   -9.06 | eps:  0.449 | loss~:  1.484
# dqn_final | Ep  850 | avg100:   -7.78 | eps:  0.427 | loss~:  1.614
# dqn_final | Ep  900 | avg100:   -0.12 | eps:  0.406 | loss~:  1.645
# dqn_final | Ep  950 | avg100:   10.33 | eps:  0.387 | loss~:  1.700
# dqn_final | Ep 1000 | avg100:   18.33 | eps:  0.368 | loss~:  1.656
# dqn_final | Ep 1050 | avg100:   22.74 | eps:  0.350 | loss~:  1.626
# dqn_final | Ep 1100 | avg100:   32.55 | eps:  0.333 | loss~:  1.581
# dqn_final | Ep 1150 | avg100:   44.63 | eps:  0.316 | loss~:  1.540
# dqn_final | Ep 1200 | avg100:   48.11 | eps:  0.301 | loss~:  1.426
# dqn_final | Ep 1250 | avg100:   57.74 | eps:  0.286 | loss~:  1.585
# dqn_final | Ep 1300 | avg100:   72.22 | eps:  0.272 | loss~:  1.449
# dqn_final | Ep 1350 | avg100:   67.37 | eps:  0.259 | loss~:  1.421
# dqn_final | Ep 1400 | avg100:   80.51 | eps:  0.246 | loss~:  1.357
# dqn_final | Ep 1450 | avg100:   90.44 | eps:  0.234 | loss~:  1.376
# dqn_final | Ep 1500 | avg100:   79.61 | eps:  0.223 | loss~:  1.284
# dqn_final | Ep 1550 | avg100:   75.18 | eps:  0.212 | loss~:  1.239
# dqn_final | Ep 1600 | avg100:   83.56 | eps:  0.202 | loss~:  1.283
# dqn_final | Ep 1650 | avg100:   97.20 | eps:  0.192 | loss~:  1.349
# dqn_final | Ep 1700 | avg100:  103.47 | eps:  0.183 | loss~:  1.366
# dqn_final | Ep 1750 | avg100:  115.66 | eps:  0.174 | loss~:  1.302
# dqn_final | Ep 1800 | avg100:  138.31 | eps:  0.165 | loss~:  1.165
# dqn_final | Ep 1850 | avg100:  163.90 | eps:  0.157 | loss~:  1.098
# dqn_final | Ep 1900 | avg100:  171.25 | eps:  0.149 | loss~:  1.056
# dqn_final | Ep 1950 | avg100:  156.60 | eps:  0.142 | loss~:  1.056
# dqn_final | Ep 2000 | avg100:  170.18 | eps:  0.135 | loss~:  0.978
#
#  dqn_final solved at ep 2042 | avg100 200.48 | continue until ep 2500 | finetune_lr 0.0001
#
# dqn_final | Ep 2050 | avg100:  207.56 | eps:  0.129 | loss~:  0.817
# dqn_final | Ep 2100 | avg100:  228.75 | eps:  0.122 | loss~:  0.792
# dqn_final | Ep 2150 | avg100:  245.57 | eps:  0.116 | loss~:  0.810
# dqn_final | Ep 2200 | avg100:  248.12 | eps:  0.111 | loss~:  0.780
# dqn_final | Ep 2250 | avg100:  236.45 | eps:  0.105 | loss~:  0.760
# dqn_final | Ep 2300 | avg100:  242.86 | eps:  0.100 | loss~:  0.719
# dqn_final | Ep 2350 | avg100:  257.08 | eps:  0.095 | loss~:  0.751
# dqn_final | Ep 2400 | avg100:  252.11 | eps:  0.091 | loss~:  0.683
# dqn_final | Ep 2450 | avg100:  253.92 | eps:  0.086 | loss~:  0.641
# dqn_final | Ep 2500 | avg100:  259.52 | eps:  0.082 | loss~:  0.683
#
# FINAL mean across seeds: 255.76888420438908 | std: 15.297901198616314
# dqn_best_gif | Ep   50 | avg100: -170.52 | eps:  0.951 | loss~:  1.433
# dqn_best_gif | Ep  100 | avg100: -158.14 | eps:  0.905 | loss~:  1.362
# dqn_best_gif | Ep  150 | avg100: -125.48 | eps:  0.861 | loss~:  1.386
# dqn_best_gif | Ep  200 | avg100: -105.59 | eps:  0.819 | loss~:  1.272
# dqn_best_gif | Ep  250 | avg100: -101.65 | eps:  0.779 | loss~:  1.309
# dqn_best_gif | Ep  300 | avg100:  -91.43 | eps:  0.741 | loss~:  1.189
# dqn_best_gif | Ep  350 | avg100:  -79.84 | eps:  0.705 | loss~:  1.291
# dqn_best_gif | Ep  400 | avg100:  -66.90 | eps:  0.670 | loss~:  1.322
# dqn_best_gif | Ep  450 | avg100:  -58.61 | eps:  0.637 | loss~:  1.421
# dqn_best_gif | Ep  500 | avg100:  -51.48 | eps:  0.606 | loss~:  1.321
# dqn_best_gif | Ep  550 | avg100:  -43.79 | eps:  0.577 | loss~:  1.291
# dqn_best_gif | Ep  600 | avg100:  -40.05 | eps:  0.549 | loss~:  1.342
# dqn_best_gif | Ep  650 | avg100:  -31.76 | eps:  0.522 | loss~:  1.345
# dqn_best_gif | Ep  700 | avg100:  -23.68 | eps:  0.496 | loss~:  1.425
# dqn_best_gif | Ep  750 | avg100:  -12.88 | eps:  0.472 | loss~:  1.524
# dqn_best_gif | Ep  800 | avg100:   -9.06 | eps:  0.449 | loss~:  1.484
# dqn_best_gif | Ep  850 | avg100:   -7.78 | eps:  0.427 | loss~:  1.614
# dqn_best_gif | Ep  900 | avg100:   -0.12 | eps:  0.406 | loss~:  1.645
# dqn_best_gif | Ep  950 | avg100:   10.33 | eps:  0.387 | loss~:  1.700
# dqn_best_gif | Ep 1000 | avg100:   18.33 | eps:  0.368 | loss~:  1.656
# dqn_best_gif | Ep 1050 | avg100:   22.74 | eps:  0.350 | loss~:  1.626
# dqn_best_gif | Ep 1100 | avg100:   32.55 | eps:  0.333 | loss~:  1.581
# dqn_best_gif | Ep 1150 | avg100:   44.63 | eps:  0.316 | loss~:  1.540
# dqn_best_gif | Ep 1200 | avg100:   48.11 | eps:  0.301 | loss~:  1.426
# dqn_best_gif | Ep 1250 | avg100:   57.74 | eps:  0.286 | loss~:  1.585
# dqn_best_gif | Ep 1300 | avg100:   72.22 | eps:  0.272 | loss~:  1.449
# dqn_best_gif | Ep 1350 | avg100:   67.37 | eps:  0.259 | loss~:  1.421
# dqn_best_gif | Ep 1400 | avg100:   80.51 | eps:  0.246 | loss~:  1.357
# dqn_best_gif | Ep 1450 | avg100:   90.44 | eps:  0.234 | loss~:  1.376
# dqn_best_gif | Ep 1500 | avg100:   79.61 | eps:  0.223 | loss~:  1.284
# dqn_best_gif | Ep 1550 | avg100:   75.18 | eps:  0.212 | loss~:  1.239
# dqn_best_gif | Ep 1600 | avg100:   83.56 | eps:  0.202 | loss~:  1.283
# dqn_best_gif | Ep 1650 | avg100:   97.20 | eps:  0.192 | loss~:  1.349
# dqn_best_gif | Ep 1700 | avg100:  103.47 | eps:  0.183 | loss~:  1.366
# dqn_best_gif | Ep 1750 | avg100:  115.66 | eps:  0.174 | loss~:  1.302
# dqn_best_gif | Ep 1800 | avg100:  138.31 | eps:  0.165 | loss~:  1.165
# dqn_best_gif | Ep 1850 | avg100:  163.90 | eps:  0.157 | loss~:  1.098
# dqn_best_gif | Ep 1900 | avg100:  171.25 | eps:  0.149 | loss~:  1.056
# dqn_best_gif | Ep 1950 | avg100:  156.60 | eps:  0.142 | loss~:  1.056
# dqn_best_gif | Ep 2000 | avg100:  170.18 | eps:  0.135 | loss~:  0.978
#
#  dqn_best_gif solved at ep 2042 | avg100 200.48 | continue until ep 2500 | finetune_lr 0.0001
#
# dqn_best_gif | Ep 2050 | avg100:  207.56 | eps:  0.129 | loss~:  0.817
# dqn_best_gif | Ep 2100 | avg100:  228.75 | eps:  0.122 | loss~:  0.792
# dqn_best_gif | Ep 2150 | avg100:  245.57 | eps:  0.116 | loss~:  0.810
# dqn_best_gif | Ep 2200 | avg100:  248.12 | eps:  0.111 | loss~:  0.780
# dqn_best_gif | Ep 2250 | avg100:  236.45 | eps:  0.105 | loss~:  0.760
# dqn_best_gif | Ep 2300 | avg100:  242.86 | eps:  0.100 | loss~:  0.719
# dqn_best_gif | Ep 2350 | avg100:  257.08 | eps:  0.095 | loss~:  0.751
# dqn_best_gif | Ep 2400 | avg100:  252.11 | eps:  0.091 | loss~:  0.683
# dqn_best_gif | Ep 2450 | avg100:  253.92 | eps:  0.086 | loss~:  0.641
# dqn_best_gif | Ep 2500 | avg100:  259.52 | eps:  0.082 | loss~:  0.683
# Saved GIF: runs_lunarlander\dqn_best_gif_seed999_best.gif | return: 270.97

# %% [markdown]
# # 9. DIFFERENCIATOR: stress-test wind (evaluation only)

# %%
def make_env(seed: int, **make_kwargs):
    import gymnasium as gym
    env = gym.make(ENV_ID, **make_kwargs)
    env.reset(seed=seed)
    env.action_space.seed(seed)
    return env

# %%
@torch.no_grad()
def evaluate_dqn(agent, n_episodes=20, seed=0, max_steps=1000, **make_kwargs):
    env = make_env(seed + 10_000, **make_kwargs)
    returns, lengths = [], []

    for ep in range(n_episodes):
        s, _ = env.reset(seed=seed + 10_000 + ep)
        ep_ret, ep_len = 0.0, 0

        for _ in range(max_steps):
            a = agent.act(s, eps=0.0)
            s, r, terminated, truncated, _ = env.step(a)
            ep_ret += float(r)
            ep_len += 1
            if terminated or truncated:
                break

        returns.append(ep_ret)
        lengths.append(ep_len)

    env.close()
    return float(np.mean(returns)), float(np.std(returns, ddof=1)), returns, lengths

# %%
wind_kwargs = dict(enable_wind=True, wind_power=10.0, turbulence_power=1.0)

def eval_saved_model_under_wind(model_path, seed=0, n_episodes=20, max_steps=1000):
    # create env just to get dims (optional)
    env = make_env(seed, **wind_kwargs)
    obs_dim = env.observation_space.shape[0]
    act_dim = env.action_space.n
    env.close()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    agent = DQNAgent(obs_dim, act_dim, seed=seed)
    agent.q.load_state_dict(torch.load(model_path, map_location=device))
    agent.q.eval()
    agent.q_tgt.load_state_dict(agent.q.state_dict())

    mean_w, std_w, _, _ = evaluate_dqn(
        agent, n_episodes=n_episodes, seed=seed, max_steps=max_steps, **wind_kwargs
    )
    return mean_w, std_w

best_seed = max(dqn_final, key=lambda x: x["eval_mean"])
mw, sw = eval_saved_model_under_wind(best_seed["model_path"], seed=best_seed["seed"], n_episodes=20)
print(f"Wind stress-test (20 eps) mean±std: {mw:.2f} ± {sw:.2f} | wind_power=10 | turbulence=1.0")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 21
#      16     mean_w, std_w, _, _ = evaluate_dqn(
#      17         agent, n_episodes=n_episodes, seed=seed, max_steps=max_steps, **wind_kwargs
#      18     )
#      19     return mean_w, std_w
# ---> 21 best_seed = max(dqn_final, key=lambda x: x["eval_mean"])
#      22 mw, sw = eval_saved_model_under_wind(best_seed["model_path"], seed=best_seed["seed"], n_episodes=20)
#      23 print(f"Wind stress-test (20 eps) mean±std: {mw:.2f} ± {sw:.2f} | wind_power=10 | turbulence=1.0")
#
# NameError: name 'dqn_final' is not defined
